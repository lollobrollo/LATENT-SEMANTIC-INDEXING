# %% [markdown]
# # An Inefficient Vector Space Model

# %%
# Import defaultdict from the collections module.
# defaultdict is a dictionary-like object which provides a default value for a key that does not exist.
# so there is no error if the key does not exist
from collections import defaultdict

# Import log and sqrt functions from the math module.
# log is used for calculating logarithms and sqrt for calculating square roots.
from math import log, sqrt

# Import the re module for regular expression operations.
# This module provides support for regular expressions (pattern matching in strings).
import re

# %% [markdown]
# The dataset is the TIME dataset, available at http://ir.dcs.gla.ac.uk/resources/test_collections/time/

# %%
def import_dataset():
    """
    This function imports all the articles in the TIME corpus,
    returning a list of lists where each sub-list contains all the
    terms present in the document as a string.
    """
    # Initialize an empty list to store the articles.
    articles = []

    # Open the 'TIME.ALL' file in read mode.
    with open('data/TIME.ALL', 'r') as f:
        # Initialize a temporary list to store words of the current article.
        tmp = []

        # Iterate over each row in the file.
        for row in f:
            # Check if the row starts with '*TEXT', indicating a new article.
            if row.startswith("*TEXT"):
                # If tmp is not empty, it means we have reached a new article.
                # Add the previous article's words to the articles list.
                if tmp != []:
                    articles.append(tmp)
                # Reset tmp for the new article.
                tmp = []
            else:
                # Remove any non-alphabetic characters and split the row into words.
                # Regular expression is used here to replace non-letter characters with nothing ('').
                row = re.sub(r'[^a-zA-Z\s]+', '', row)
                # Extend the temporary list with the words from this row.
                tmp += row.split()

        # If the last article was not followed by a new '*TEXT', add it to the articles list.
        if tmp != []:
            articles.append(tmp)

    # Return the list of articles.
    return articles

# %%
def make_inverted_index(articles):
    """
    This function builds an inverted index as a hash table (dictionary)
    where the keys are the terms and the values are ordered sets of
    docIDs containing the term.
    """
    # Create a defaultdict where each key will have a set as its default value.
    # This is used to store the inverted index.
    index = defaultdict(set)

    # Enumerate over the articles, getting both the index (docid) and the article.
    # The index acts as a unique identifier for each document.
    for docid, article in enumerate(articles):
        # Iterate over each term in the article.
        for term in article:
            # Add the document ID to the set of docIDs for this term.
            # Since it's a set, each docID will be unique per term.
            index[term].add(docid)

    # Return the constructed inverted index.
    return index

# %%
index = defaultdict(set)

# %%
index["home"].add(1)
index["home"].add(2)
index["yes"].add(2)
index["more"].add(3)

# %%
index
# Out:
# defaultdict(set, {'home': {1, 2}, 'yes': {2}, 'more': {3}})

# %%
def make_positional_index(articles):
    """
    A more advanced version of make_inverted_index.
    This function builds a positional inverted index as a dictionary. 
    Here, for each term in the articles, the index stores a dictionary 
    where the keys are document IDs and the values are lists of positions 
    where the term appears in the document.
    """
    # Create a defaultdict of dictionaries. The outer dictionary holds terms,
    # and the inner dictionary maps document IDs to a list of positions.
    index = defaultdict(dict)

    # Enumerate over the articles to get both the document ID (docid) and the article itself.
    for docid, article in enumerate(articles):
        # Enumerate over each term in the article to get both the position (pos) and the term.
        for pos, term in enumerate(article):
            try:
                # Try to append the position to the existing list for this term in this document.
                index[term][docid].append(pos)
            except KeyError:
                # If the term or document ID doesn't exist yet in the index,
                # create a new entry with the current position in a list.
                index[term][docid] = [pos]

    # Return the constructed positional inverted index.
    return index

# %%
articles = [["home","no","yes", "home"],[ "more", "advanced", "version","no","yes"]]

# %%
make_positional_index(articles)
# Out:
# defaultdict(dict,
#             {'home': {0: [0, 3]},
#              'no': {0: [1], 1: [3]},
#              'yes': {0: [2], 1: [4]},
#              'more': {1: [0]},
#              'advanced': {1: [1]},
#              'version': {1: [2]}})

# %%
def documents_as_vectors(articles):
    """
    This function generates a list of dictionaries, where each dictionary represents 
    the TF-IDF vector of a document. Each term's TF-IDF value is calculated and 
    stored in the dictionary. This function is suitable for small collections 
    as its space complexity is O(#documents x #terms).
    """
    # Generate a positional index from the articles
    p_index = make_positional_index(articles)

    # Initialize an empty list to store the TF-IDF vectors of each document
    vectors = []

    # Calculate the total number of documents
    n = len(articles)

    # Calculate the Inverse Document Frequency (IDF) for each term
    idf = {}
    for term in p_index.keys():
        idf[term] = log(n / len(p_index[term]))

    # Iterate over each document to create its TF-IDF vector
    for docid in range(0, len(articles)):
        # Initialize an empty dictionary for the TF-IDF vector of the current document
        v = {}

        # Calculate TF-IDF for each term and store it in the vector
        for term in p_index.keys():
            try:
                # Term Frequency (TF) is the number of times a term occurs in this document
                # Multiply TF with IDF to get TF-IDF
                tfidf = len(p_index[term][docid]) * idf[term]
            except KeyError:
                # If the term is not in the document, its TF-IDF is 0
                tfidf = 0

            # Assign the TF-IDF score to the term in the vector
            v[term] = tfidf

        # Add the document's TF-IDF vector to the list
        vectors.append(v)

    # Return the list of TF-IDF vectors
    return vectors

# %%
p_index = make_positional_index(articles)
p_index.keys()
# Out:
# dict_keys(['home', 'no', 'yes', 'more', 'advanced', 'version'])

# %%
len(p_index['home'][0]), len(p_index['no'][0])
# Out:
# (2, 1)

# %%
def show_document_vector(v, docid):
    """
    This function prints the terms and their corresponding non-zero TF-IDF weights 
    (both normalized and unnormalized) for a given document represented as a vector in v.
    """
    # Create a list of terms with non-zero weights in the specified document's vector.
    non_zero_terms = [x for x in v[docid].keys() if v[docid][x] > 0]

    # Create a list of tuples (term, TF-IDF weight) for the non-zero terms.
    vector = [(x, v[docid][x]) for x in non_zero_terms]

    # Sort the vector in descending order based on the TF-IDF weights.
    vector.sort(key=lambda x: x[1], reverse=True)

    # Calculate the length of the vector (Euclidean norm) for normalization.
    length = sqrt(sum([x[1]**2 for x in vector]))

    # Normalize the vector by dividing each TF-IDF weight by the vector's length.
    normalized = {k: tfidf/length for k, tfidf in vector}

    # Print each term along with its unnormalized and normalized TF-IDF weight.
    for (term, tfidf) in vector:
        print(f"{term}:\t{tfidf}\t(normalized: {normalized[term]})")

# %%
# Example of usage
articles = import_dataset()
vectors = documents_as_vectors(articles)

# %%
len(articles)
# Out:
# 423

# %%
" ".join(articles[0])
# Out:
# 'THE ALLIES AFTER NASSAU IN DECEMBER THE US FIRST PROPOSED TO HELP NATO DEVELOP ITS OWN NUCLEAR STRIKE FORCE BUT EUROPE MADE NO ATTEMPT TO DEVISE A PLAN LAST WEEK AS THEY STUDIED THE NASSAU ACCORD BETWEEN PRESIDENT KENNEDY AND PRIME MINISTER MACMILLAN EUROPEANS SAW EMERGING THE FIRST OUTLINES OF THE NUCLEAR NATO THAT THE US WANTS AND WILL SUPPORT IT ALL SPRANG FROM THE ANGLOUS CRISIS OVER CANCELLATION OF THE BUGRIDDEN SKYBOLT MISSILE AND THE US OFFER TO SUPPLY BRITAIN AND FRANCE WITH THE PROVED POLARIS TIME DEC THE ONE ALLIED LEADER WHO UNRESERVEDLY WELCOMED THE POLARIS OFFER WAS HAROLD MACMILLAN WHO BY THUS KEEPING A SEPARATE NUCLEAR DETERRENT FOR BRITAIN HAD SAVED HIS OWN NECK BACK FROM NASSAU THE PRIME MINISTER BEAMED THAT BRITAIN NOW HAD A WEAPON THAT WILL LAST A GENERATION THE TERMS ARE VERY GOOD MANY OTHER BRITONS WERE NOT SO SURE THOUGH THE GOVERNMENT WILL SHOULDER NONE OF THE MILLION DEVELOPMENT COST OF POLARIS IT HAS ALREADY POURED MILLION INTO SKYBOLT AND WILL HAVE TO SPEND PERHAPS BILLION MORE FOR A FLEET OF MISSILEPACKING SUBMARINES AT BEST THE BRITISH WILL NOT BE ABLE TO DESIGN BUILD AND PROVE ITS NUCLEAR FLEET BEFORE THREE YEARS AFTER BRITAINS BOMBER FORCE HAS PRESUMABLY BECOME OBSOLETE THEN WHAT TORY BACKBENCHERS ARE LOUDLY SKEPTICAL OF WHAT THEY CALL THE SMALL TYPE IN THE NASSAU PACT WHICH STIPULATES THAT BRITAINS POLARIS SUBMARINE FLEET EXCEPT WHEN SUPREME NATIONAL INTERESTS INTERVENE MUST BE COMMITTED TO A TRULY MULTILATERAL NATO FORCE DOES THAT MEAN THAT BRITAIN WILL EVENTUALLY HAVE NO STRIKE FORCE OF ITS OWN WHO WILL DECIDE WHEN OR WHETHER NATIONAL INTERESTS JUSTIFY WITHDRAWAL OF SUBMARINES FROM NATO PARTICULARLY IF THOSE NATIONAL INTERESTS CONFLICT WITH US POLICY THE BIGGEST QUESTION OF ALL IS WHETHER FRANCES INCLUSION IN THE OFFER WAS A DELIBERATE PLOY BY JACK KENNEDY TO END OR AT LEAST DOWNGRADE BRITAINS PRIZED SPECIAL RELATIONSHIP WITH THE US THE CARTOONISTS WENT EVEN FARTHER THEY NOT ONLY SHOWED SUPERMAC JUMPING TO SUPERJACKS COMMANDS BUT DE GAULLE AND ADENAUER AS WELL AS EDITH SAID THE FRENCH WHO GOT NO HELP FROM THE US IN DEVELOPING THEIR FORCE DE FRAPPE WERE QUICK TO CROW THAT BRITAINS VAUNTED TIES WITH THE US HAD BROUGHT IT NOTHING BUT HUMILIATION BY CONTRAST BRAGGED FRENCH OFFICIALS THE SKYBOLT FIASCO ONLY VINDICATED FRANCES DECISION TO DEVELOP ITS OWN BOMBS AND DELIVERY SYSTEMS THUS THOUGH CHARLES DE GAULLE PROMISED TO REFLECT ON THE POLARIS OFFER THERE WAS LITTLE LIKELIHOOD THAT HE WOULD ACCEPT ANY OFFER THAT WOULD SUBJECT A FRENCH FORCE TO ALLIED CONTROL IT IS DE GAULLES UNSWERVING CONVICTION THAT IF THE RUSSIANS WERE ACTUALLY TO INVADE WESTERN EUROPE NO NATION THAT WAS NOT DIRECTLY ATTACKED MEANING THE US WOULD INVITE NUCLEAR DEVASTATION BY HELPING ITS ALLIES THUS UNLIKE BRITAINS BOMBER FORCE WHICH ALL ALONG HAS BEEN PLEDGED TO THE WESTERN STRATEGIC DETERRENT FRANCES FORCE DE FRAPPE WILL BE RESPONSIBLE ONLY FOR FRANCES DEFENSE AT THE SAME TIME DE GAULLE HAS LONG ARGUED THAT THE ATLANTIC ALLIANCE COULD BE RUN MOST EFFICIENTLY BY A TRIUMVIRATE THAT WOULD INCLUDE FRANCE AS AN EQUAL OF THE US AND BRITAIN THIS IS ONE OF HIS MAJOR IF UNSPOKEN CONDITIONS FOR BRITISH MEMBERSHIP IN THE COMMON MARKET AND DE GAULLE SUGGESTED POINTEDLY TO MACMILLAN THAT IT WOULD HELP IF BRITAIN WERE TO SHARE ITS ADVANCED MISSILE TECHNOLOGY WITH FRANCE WHEN MACMILLAN REPLIED NONCOMMITTALLY THAT HE WOULD HAVE TO DISCUSS THIS WITH KENNEDY DE GAULLE TOLD HIS GUEST WITH HAUTEUR THAT FRANCE IN THAT CASE COULD DO NOTHING TO EASE BRITAINS ENTRY INTO EUROPE GOITALONE GRANDEUR KONRAD ADENAUER ON THE OTHER HAND IS FEARFUL THAT DE GAULLE WILL SNAP UP THE POLARIS OFFER AND IN THIS WAY ACHIEVE HIS GOAL OF A THREENATION NATO DIRECTORATE THOUGH HIS GOVERNMENT VOWED IN NOT TO MANUFACTURE NUCLEAR WEAPONS ADENAUER HAS BECOME INCREASINGLY APPREHENSIVE THAT WITHOUT THEM AND WITH NO SAY IN THEIR USE WEST GERMANY WILL BE RELEGATED TO SECONDCLASS CITIZENSHIP IN THE ALLIANCE LAST WEEK AN OFFICIAL BULLETIN EVEN REVIVED THE OLD BITTER CRY THAT US P ...

# %%
vectors[0]
# Out:
# {'THE': 0.0,
#  'ALLIES': 5.042023308860233,
#  'AFTER': 1.9206012227584774,
#  'NASSAU': 16.40584811996386,
#  'IN': 0.02366865010266244,
#  'DECEMBER': 3.4083148494310196,
#  'US': 11.311010314826785,
#  'FIRST': 3.3297456857491694,
#  'PROPOSED': 2.789275641024796,
#  'TO': 0.06390535527718859,
#  'HELP': 5.618954727451922,
#  'NATO': 14.00280067405182,
#  'DEVELOP': 7.9358612747328845,
#  'ITS': 3.433808821427182,
#  'OWN': 3.8391033752555757,
#  'NUCLEAR': 22.63182545128017,
#  'STRIKE': 5.2267699491222634,
#  'FORCE': 13.730252417975137,
#  'BUT': 0.4506549342286122,
#  'EUROPE': 5.7607133820035585,
#  'MADE': 1.1798377285906956,
#  'NO': 3.024772342622422,
#  'ATTEMPT': 2.4920241175568645,
#  'DEVISE': 5.354224998486333,
#  'A': 0.0,
#  'PLAN': 2.1972245773362196,
#  'LAST': 0.38691850583420445,
#  'WEEK': 0.4671839016615207,
#  'AS': 0.6673567705823108,
#  'THEY': 1.3803705619380855,
#  'STUDIED': 3.9679306373664422,
#  'ACCORD': 4.437934266612178,
#  'BETWEEN': 1.4029812799049053,
#  'PRESIDENT': 2.254782506436306,
#  'KENNEDY': 9.33520044936788,
#  'AND': 0.11387948430182328,
#  'PRIME': 3.3058460487476786,
#  'MINISTER': 2.0868517462016376,
#  'MACMILLAN': 11.31398541671231,
#  'EUROPEANS': 2.956329725687962,
#  'SAW': 3.002849741322855,
#  'EMERGING': 4.255612709818223,
#  'OUTLINES': 6.0473721790462776,
#  'OF': 0.0,
#  'THAT': 1.4602690539103629,
#  'WANTS': 2.463853240590168,
#  'WILL': 8.460455124977603,
#  'SUPPORT': 1.7298840655099674,
#  'IT': 1.5084279123393283,
#  'ALL': 1.7662804510011227,
#  'SPRANG': 6.0473721790462776,
#  'FROM': 0.8481819863331945,
#  'ANGLOUS': 6.0473721790462776,
#  'CRISIS': 2.218730782557183,
#  'OVER': 0.6583004492297772,
#  'CANCELLATION': 4.948759890378168,
#  'BUGRIDDEN': 5.354224998486333,
#  'SKYBOLT': 13.313802799836534,
#  'MISSILE': 6.678643955888136,
#  'OFFER': 16.735653846148775,
#  'SUPPLY': 2.715167668871074,
#  'BRITAIN': 10.911150665198967,
#  'FRANCE': 8.51783378596297,
#  'WITH': 0.5478913131612483,
#  'PROVED': 2.5508646175797978,
#  'POLARIS': 23.375253845608476,
#  'TIME': 1.4782089632901465,
#  'DEC': 3.8501476017100584,
#  'ONE': 0.7005573850817469,
#  'ALLIED': 7.298953812495815,
#  'LEADER': 1.5255836019972375,
#  'WHO': 1.3743588175603074,
#  'UNRESERVEDLY': 6.0473721790462776,
#  'WELCOMED': 3.5624655292582776,
#  'WAS': 0.3973487594625282,
#  'HAROLD': 2.5816362762465515,
#  'BY': 0.8520619859502464,
#  'THUS': 6.066061464933386,
#  'KEEPING': 3.1570004211501135,
#  'SEPARATE': 3.1570004211501135,
#  'DETERRENT': 13.633259397724078,
#  'FOR': 0.15274927052463683,
#  'HAD': 0.8748898963780976,
#  'SAVED': 3.6494769062479073,
#  'HIS': 1.085424732677887,
#  'NECK': 4.255612709818223,
#  'BACK': 1.0300923422313535,
#  'BEAMED': 4.437934266612178,
#  'NOW': 0.8655886287541927,
#  'WEAPON': 3.8501476017100584,
#  'GENERATION': 3.4824228215847413,
#  'TERMS': 2.680076349059804,
#  'ARE': 1.6753033586687747,
#  'VERY': 1.9042374526547452,
#  'GOOD': 1.5255836019972375,
#  'MANY': 1.127391253218153,
#  'OTHER': 1.6112503279732713,
#  'BRITONS': 3.339321977944068,
#  'WERE': 1.1665198618374635,
#  'NOT': 1.6555863354975728,
#  'SO': 0.8599863732055231,
#  'SURE': 2.680076349059804,
#  'THOUGH': 3.6332708162844,
#  'GOVERNMENT': 1.2625435536837155,
#  'SHOULDER': 3.6494769062479073,
#  'NONE': 2.6461747973841225,
#  'MILLION': 3.1400707291361427,
#  'DEVELOPMENT': 3.002849741322855,
#  'COST': 5.2267699491222634,
#  'HAS': 1.9220584945516603,
#  'ALREADY': 3.355848653158513,
#  'POURED': 3.002849741322855,
#  'INTO': 1.1502030107496064,
#  'HAVE': 1.4824735071119846,
#  'SPEND': 3.4083148494310196,
#  'PERHAPS': 2.3584927249323417,
#  'BILLION': 2.9118779631171283,
#  'MORE': 1.0279653806375153,
#  'FLEET': 10.860670675484297,
#  'MISSILEPACKING': 6.0473721790462776,
#  'SUBMARINES': 7.9358612747328845,
#  'AT': 0.9509653242803818,
#  'BEST': 2.218730782557183,
#  'BRITISH': 5.650572763266569,
#  'BE': 2.3077632413519784,
#  'ABLE': 2.3097025607629096,
#  'DESIGN': 3.6494769062479073,
#  'BUILD': 2.751535313041949,
#  'PROVE': 3.002849741322855,
#  'BEFORE': 1.0434258731008188,
#  'THREE': 0.8599863732055231,
#  'YEARS': 0.6674748255058185,
#  'BRITAINS': 11.425424715928472,
#  'BOMBER': 9.897519780756337,
#  'PRESUMABLY': 2.956329725687962,
#  'BECOME': 3.776978191373212,
#  'OBSOLETE': 9.322155635852775,
#  'THEN': 0.99112637369797,
#  'WHAT': 1.9695542920386224,
#  'TORY': 2.9118779631171283,
#  'BACKBENCHERS': 4.437934266612178,
#  'LOUDLY': 4.255612709818223,
#  'SKEPTICAL': 3.6494769062479073,
#  'CALL': 2.0961284604648505,
#  'SMALL': 2.0043209112117277,
#  'TYPE': 3.8501476017100584,
#  'PACT': 3.744787086052232,
#  'WHICH': 1.5657577197434822,
#  'STIPULATES': 6.0473721790462776,
#  'SUBMARINE': 3.8501476017100584,
#  'EXCEPT': 5.430335337742148,
#  'WHEN': 1.369155595606264,
#  'SUPREME': 3.9679306373664422,
#  'NATIONAL': 4.180235486666263,
#  'INTERESTS': 10.22494454829306,
#  'INTERVENE': 4.661077817926388,
#  'MUST': 1.7988769369969189,
#  'COMMITTED': 3.1029331998798377,
#  'TRULY': 4.255612709818223,
#  'MULTILATERAL': 7.9358612747328845,
#  'DOES': 4.481419378551917,
#  'MEAN': 3.274783456806497,
#  'EVENTUALLY': 5.912659451375924,
#  'DECIDE': 3.339321977944068,
#  'OR': 2.897448799631479,
#  'WHETHER': 4.311103761871303,
#  'JUSTIFY': 5.354224998486333,
#  'WITHDRAWAL': 3.214158834990062,
#  'PARTICULARLY': 3.1570004211501135,
#  'IF': 3.5532675193269956,
#  'THOSE': 1.888489095686606,
#  'CONFLICT': 3.339321977944068,
#  'POLICY': 2.0043209112117277,
#  'BIGGEST': 2.5508646175797978,
#  'QUESTION': 2.135349173618132,
#  'IS': 1.3461017979069558,
#  'FRANCES': 10.453539898244527,
#  'INCLUSION': 4.948759890378168,
#  'DELIBERATE': 4.255612709818223,
#  'PLOY': 4.948759890378168,
#  'JACK': 3.8501476017100584,
#  'END': 1.2515816334495369,
#  'LEAST': 3.2570631424993604,
#  'DOWNGRADE': 5.354224998486333,
#  'PRIZED': 5.354224998486333,
#  'SPECIAL': 2.3097025607629096,
#  'RELATIONSHIP': 4.255612709818223,
#  'CARTOONISTS': 6.0473721790462776,
#  'WENT': 1.536512672529428,
#  'EVEN': 1.4981096249964827,
#  'FARTHER': 3.744787086052232,
#  'ONLY': 2.851308881211081,
#  'SHOWED': 2.263182545128017,
#  'SUPERMAC': 6.0473721790462776,
#  'JUMPING': 4.948759890378168,
#  'SUPERJACKS': 6.0473721790462776,
#  'COMMANDS': 3.744787086052232,
#  'DE': 19.326040116876754,
#  'GAULLE': 15.088863166549562,
#  'ADENAUER': 9.15491971647686,
#  'WELL': 2.7678661698684217,
#  'EDITH': 6.0473721790462776,
#  'SAID': 1.253674359547984,
#  'FRENCH': 7.79367904657069,
#  'GOT': 1.472661200542895,
#  'DEVELOPING': 4.948759890378168,
#  'THEIR': 0.9420927064455977,
#  'FRAPPE': 11.550442805130174,
#  'QUICK': 3.339321977944068,
#  'CROW': 5.354224998486333,
#  'VAUNTED': 4.661077817926388,
#  'TIES': 3.4083148494310196,
#  'BROUGHT': 1.9202377940011863,
#  'NOTHING': 6.656192347671549,
#  'HUMILIATION': 4.948759890378168,
#  'CONTRAST': 3.4083148494310196,
#  'BRAGGED': 5.354224998486333,
#  'OFFICIALS': 1.6779243265792565,
#  'FIASCO': 4.948759890378168,
#  'VINDICATED': 6.0473721790462776,
#  'DECISION': 2.5508646175797978,
#  'BOMBS': 3.339321977944068,
#  'DELIVERY': 3.9679306373664422,
#  'SYSTEMS': 4.101462029990965,
#  'CHARLES': 4.192256920929701,
#  'PROMISED': 2.3584927249323417,
#  'REFLECT': 4.948759890378168,
#  'ON': 0.38691850583420445,
#  'THERE': 0.6446947971739986,
#  'LITTLE': 1.2270906134412412,
#  'LIKELIHOOD': 4.437934266612178,
#  'HE': 0.46648329444242315,
#  'WOULD': 3.7081593005510234,
#  'ACCEPT': 2.5210116544301164,
#  'ANY': 2.1830902428900343,
#  'SUBJECT': 3.339321977944068,
#  'CONTROL': 1.7569127378978868,
#  'GAULLES': 2.6133849745611317,
#  'UNSWERVING': 5.354224998486333,
#  'CONVICTION': 4.437934266612178,
#  'RUSSIANS': 4.572344126705431,
#  'ACTUALLY': 2.176171168138387,
#  'INVADE': 5.354224998486333,
#  'WESTERN': 3.1400707291361427,
#  'NATION': 1.7569127378978868,
#  'DIRECTLY': 3.339321977944068,
#  'ATTACKED': 3.002849741322855,
#  'MEANING': 3.4083148494310196,
#  'INVITE': 5.354224998486333,
#  'DEVASTATION': 6.0473721790462776,
#  'HELPING': 3.744787086052232,
#  'UNLIKE': 3.214158834990062,
#  'ALONG': 1.6906633523566863,
#  'BEEN': 0.4752181468685135,
#  'PLEDGED': 3.6494769062479073,
#  'STRATEGIC': 6.103279810984573,
#  'RESPONSIBLE': 3.214158834990062,
#  'DEFENSE': 1.6653455443723963,
#  'SAME': 1.6779243265792565,
#  'LONG': 1.2766875545806133,
#  'ARGUED': 2.956329725687962,
#  'ATLANTIC': 3.0516399054922867,
#  'ALLIANCE': 5.2267699491222634,
#  'COULD': 3.3955005911218086,
#  'RUN': 2.135349173618132,
#  'MOST': 0.714653385780909,
#  'EFFICIENTLY': 4.255612709818223,
#  'TRIUMVIRATE': 5.354224998486333,
#  'INCLUDE': 3.4824228215847413,
#  'AN': 0.5332573265078973,
#  'EQUAL': 3.274783456806497,
#  'THIS': 1.7890011764417322,
#  'MAJOR': 1.9530276168241774,
#  'UNSPOKEN': 5.354224998486333,
#  'CONDITIONS': 3.1570004211501135,
#  'MEMBERSHIP': 3.0516399054922867,
#  'COMMON': 1.8577174370198524,
#  'MARKET': 1.9530276168241774,
#  'SUGGESTED': 4.7169854498646835,
#  'POINTEDLY': 4.101462029990965,
#  'SHARE': 2.715167668871074,
#  'ADVANCED': 3.4824228215847413,
#  'TECHNOLOGY': 4.101462029990965,
#  'REPLIED': 2.463853240590168,
#  'NONCOMMITTALLY': 6.0473721790462776,
#  'DISCUSS': 3.744787086052232,
#  'TOLD': 1.7569127378978868,
#  'GUEST': 3.744787086052232,
#  'HAUTEUR': 6.0473721790462776,
#  'CASE': 1.9202377940011863,
#  'DO': 1.452252328911688,
#  'EASE': 3.8501476017100584,
#  'ENTRY': 3.5624655292582776,
#  'GOITALONE': 12.094744358092555,
#  'GRANDEUR': 8.511225419636446,
#  'KONRAD': 3.1029331998798377,
#  'HAND': 2.0043209112117277,
#  'FEARFUL': 3.5624655292582776,
#  'SNAP': 4.948759890378168,
#  'UP': 0.4054651081081644,
#  'WAY': 1.3378419777339439,
#  'ACHIEVE': 3.002849741322855,
#  'GOAL': 3.5624655292582776,
#  'THREENATION': 6.0473721790462776,
#  'DIRECTORATE': 5.354224998486333,
#  'VOWED': 4.101462029990965,
#  'MANUFACTURE': 5.354224998486333,
#  'WEAPONS': 4.872908532804107,
#  'INCREASINGLY': 2.6461747973841225,
#  'APPREHENSIVE': 5.354224998486333,
#  'WITHOUT': 3.095125017432026,
#  'THEM': 0.8599863732055231,
#  'SAY': 2.0583881324820035,
#  'USE': 2.0583881324820035,
#  'WEST': 1.1645702564599072,
#  'GERMANY': 5.665467287059818,
#  'RELEGATED': 4.948759890378168,
#  'SECONDCLASS': 4.948759890378168,
#  'CITIZENSHIP': 4.661077817926388,
#  'OFFICIAL': 3.051167203994475,
#  'BULLETIN': 4.661077817926388,
#  'REVIVED': 4.661077817926388,
#  'OLD': 1.2110902720948,
#  'BITTER': 2.4364542664020536,
#  'CRY': 3.5624655292582776,
#  'PLEAS': 4.101462029990965,
#  'GREATER': 2.715167668871074,
#  'RELIANCE': 6.0473721790462776,
#  'CONVENTIONAL': 8.20292405998193,
#  'FORCES': 1.9202377940011863,
#  'AIMED': 3.214158834990062,
#  'RAISING': 4.101462029990965,
#  'GERMAN': 2.176171168138387,
#  'CANNON': 4.255612709818223,
#  'FODDER': 5.354224998486333,
#  'ATOMIC': 3.4824228215847413,
#  'KNIGHTS': 6.0473721790462776,
#  'FROSTY': 6.0473721790462776,
#  'LETTER': 3.214158834990062,
#  'CHANCELLOR': 2.789275641024796,
#  'SUPPLIES': 3.339321977944068,
#  'ALMOST': 1.716638838759947,
#  'PER': 2.786823657777509,
#  'CENT': 2.9660479751568833,
#  'GROUND': 4.819572038639785,
#  'STRENGTH': 2.5508646175797978,
#  'INTEND': 4.661077817926388,
#  'RAISE': 3.0516399054922867,
#  'DIVISIONS': 4.437934266612178,
#  'WARFARE': 3.744787086052232,
#  'YET': 1.9202377940011863,
#  'PLANNERS': 4.661077817926388,
#  'REASON': 2.33380011234197,
#  'CREDIBLE': 6.0473721790462776,
#  'SOVIET': 3.1400707291361427,
#  'ATTACK': 2.218730782557183,
#  'STRONG': 2.5816362762465515,
#  'ARMY': 1.4126431908166424,
#  'BACKED': 2.751535313041949,
#  'VAST': 2.6133849745611317,
#  'ARSENAL': 10.708449996972666,
#  'FACT': 1.6906633523566863,
#  'NEVER': 1.6285315712496802,
#  'USED': 2.0583881324820035,
#  'INDEPENDENTLY': 5.354224998486333,
#  'AGAINST': 0.9353843906897348,
#  'RUSSIA': 1.7569127378978868,
#  'INVITING': 4.661077817926388,
#  'DEVASTATING': 4.948759890378168,
#  'RETALIATION': 3.9679306373664422,
#  'EFFORTS': 3.0516399054922867,
#  'MANAGED': 2.6133849745611317,
#  'CREATE': 3.274783456806497,
#  'CAPACITY': 4.101462029990965,
#  'REPRESENTS': 3.9679306373664422,
#  'POWER': 1.4126431908166424,
#  'JUST': 1.2351878236738605,
#  'DAMNED': 4.255612709818223,
#  'NUISANCE': 6.0473721790462776,
#  'STATE': 1.2682486859347486,
#  'DEPARTMENT': 2.8284963541780774,
#  'MEANS': 2.6133849745611317,
#  'MILITARILY': 4.437934266612178,
#  'WE': 0.9293783666295229,
#  'EXPECTED': 4.767621065833263,
#  'BAIL': 5.354224998486333,
#  'OUT': 0.41975106535564094,
#  'COUNTRY': 1.1798377285906956,
#  'THROWS': 5.354224998486333,
#  'PEA': 6.0473721790462776,
#  'ANYONE': 2.5210116544301164,
#  'ELSE': 2.5816362762465515,
#  'HARDLY': 2.463853240590168,
#  'AGREE': 3.1570004211501135,
#  'UNTIL': 1.5147726858930222,
#  'BECOMES': 3.8501476017100584,
#  'MAKES': 3.0516399054922867,
#  'IMMEDIATE': 3.002849741322855,
#  'SENSE': 2.8284963541780774,
#  'TOO': 1.452252328911688,
#  'MAY': 1.3934118288887545,
#  'FIND': 2.2407096892759584,
#  'NATOCONTROLLED': 5.354224998486333,
#  'POSSIBLE': 2.2407096892759584,
#  'SUCCESSOR': 3.002849741322855,
#  'EUROPEAN': 2.040038993813807,
#  'MINUTEMAN': 6.0473721790462776,
#  'ANSWER': 2.6461747973841225,
#  'SPIRALING': 5.354224998486333,
#  'DIMINISHING': 4.255612709818223,
#  'VALUE': 4.101462029990965,
#  'WHOS': 0,
#  'CHARGE': 0,
#  'HERE': 0,
#  'NIKITA': 0,
#  'KHRUSHCHEV': 0,
#  'LAUNCHED': 0,
#  'GRANDIOSE': 0,
#  'VIRGIN': 0,
#  'LANDS': 0,
#  'GAMBLE': 0,
#  'PART': 0,
#  'PLOW': 0,
#  'ACRES': 0,
#  'MARGINAL': 0,
#  'LAND': 0,
#  'KAZAKHSTAN': 0,
#  'SETTLE': 0,
#  'COMMUNIST': 0,
#  'PIONEERS': 0,
#  'PLANT': 0,
#  'PRODUCE': 0,
#  'HUGE': 0,
#  'QUANTITIES': 0,
#  'DESPERATELY': 0,
#  'NEEDED': 0,
#  'GRAIN': 0,
#  'WITHIN': 0,
#  'TWO': 0,
#  'NIKITAS': 0,
#  'SCHEME': 0,
#  'FLOPPED': 0,
#  'ENOUGH': 0,
#  'RAINFALL': 0,
#  'DID': 0,
#  'TAKE': 0,
#  'TRACTOR': 0,
#  'LIFE': 0,
#  'BLEAK': 0,
#  'FRONTIER': 0,
#  'EACH': 0,
#  'HARVEST': 0,
#  'LOWER': 0,
#  'THAN': 0,
#  'PREVIOUS': 0,
#  'WORST': 0,
#  'YEAR': 0,
#  'DELIVERED': 0,
#  'HALF': 0,
#  'QUOTAS': 0,
#  'NATURALLY': 0,
#  'TAKES': 0,
#  'BLAME': 0,
#  'AGO': 0,
#  'FOUND': 0,
#  'SCAPEGOAT': 0,
#  'PARTY': 0,
#  'BOSS': 0,
#  'NIKOLAI': 0,
#  'BELYAEV': 0,
#  'FIRED': 0,
#  'HIM': 0,
#  'ERRORS': 0,
#  'BELYAEVS': 0,
#  'DINMUKHAMED': 0,
#  'KUNAEV': 0,
#  'SIMILARLY': 0,
#  'BOUNCED': 0,
#  'LAPSES': 0,
#  'WORK': 0,
#  'MEASURE': 0,
#  'MOSCOW': 0,
#  'ALSO': 0,
#  'PURGED': 0,
#  'FORMER': 0,
#  'PREMIER': 0,
#  'TERRITORY': 0,
#  'LOCAL': 0,
#  'PARTYS': 0,
#  'CENTRAL': 0,
#  'COMMITTEE': 0,
#  'COINCIDENCE': 0,
#  'IGNATOV': 0,
#  'ONETIME': 0,
#  'CRONY': 0,
#  'ABRUPTLY': 0,
#  'LEFT': 0,
#  'POST': 0,
#  'DEPUTY': 0,
#  'NINE': 0,
#  'MONTHS': 0,
#  'JOB': 0,
#  'FARM': 0,
#  'EXPERT': 0,
#  'MISFORTUNE': 0,
#  'BOOST': 0,
#  'FOOD': 0,
#  'PRODUCTION': 0,
#  'BERLIN': 0,
#  'HANS': 0,
#  'WEIDNER': 0,
#  'HOPING': 0,
#  'ESCAPE': 0,
#  'DRAB': 0,
#  'EAST': 0,
#  'MAKE': 0,
#  'ODDS': 0,
#  'CRIPPLE': 0,
#  'CRUTCHES': 0,
#  'LIVED': 0,
#  'VILLAGE': 0,
#  'NEUGERSDORF': 0,
#  'MILES': 0,
#  'SOUTHEAST': 0,
#  'FREEDOM': 0,
#  'ASSET': 0,
#  'BUS': 0,
#  'OPERATED': 0,
#  'REGIME': 0,
#  'UGLY': 0,
#  'THING': 0,
#  'ANCIENT': 0,
#  'CHASSIS': 0,
#  'CREAKED': 0,
#  'ENGINE': 0,
#  'COUGHED': 0,
#  'CREAMCOLORED': 0,
#  'COAT': 0,
#  'PAINT': 0,
#  'DISGUISE': 0,
#  'WELTS': 0,
#  'BRUISES': 0,
#  'DECADES': 0,
#  'CHUGGING': 0,
#  'SERVICE': 0,
#  'READY': 0,
#  'JUNK': 0,
#  'PILE': 0,
#  'DECIDED': 0,
#  'PRESS': 0,
#  'SHARP': 0,
#  'BLADES': 0,
#  'HAZARDS': 0,
#  'GREAT': 0,
#  'JOURNEY': 0,
#  'BORDER': 0,
#  'SIGNED': 0,
#  'FELLOW': 0,
#  'VILLAGER': 0,
#  'JURGEN': 0,
#  'WAGNER': 0,
#  'WHEEL': 0,
#  'EIGHT': 0,
#  'DAYS': 0,
#  'CHRISTMAS': 0,
#  'PAIR': 0,
#  'BEGAN': 0,
#  'FEVERISH': 0,
#  'PREPARATIONS': 0,
#  'WEIDNERS': 0,
#  'GARAGE': 0,
#  'ATTACHED': 0,
#  'HEAVY': 0,
#  'SNOWPLOW': 0,
#  'FRONT': 0,
#  'SNOW': 0,
#  'SCOOP': 0,
#  'AWAY': 0,
#  'OBSTACLES': 0,
#  'KNEW': 0,
#  'AWAITED': 0,
#  'ROADBLOCKS': 0,
#  'AHEAD': 0,
#  'SIX': 0,
#  'LUGS': 0,
#  'BOLTED': 0,
#  'TOUGHEST': 0,
#  'STEEL': 0,
#  'AFFIXED': 0,
#  'WHIRLING': 0,
#  'EDGES': 0,
#  'CHOP': 0,
#  'BARBED': 0,
#  'WIRE': 0,
#  'BITS': 0,
#  'WEDGED': 0,
#  'ONEQUARTERINCH': 0,
#  'SECTIONS': 0,
#  'PLATE': 0,
#  'INSIDE': 0,
#  'STOP': 0,
#  'BULLETS': 0,
#  'EVE': 0,
#  'PILED': 0,
#  'WIVES': 0,
#  'FOUR': 0,
#  'CHILDREN': 0,
#  'ABOARD': 0,
#  'FORGETTING': 0,
#  'TONS': 0,
#  'HOUSEHOLD': 0,
#  'BELONGINGS': 0,
#  'ADDED': 0,
#  'PROTECTION': 0,
#  'PLOTTERS': 0,
#  'SHOVELED': 0,
#  'TON': 0,
#  'COAL': 0,
#  'POTATOES': 0,
#  'CHUGGED': 0,
#  'OFF': 0,
#  'NORTH': 0,
#  'TOWARD': 0,
#  'ROADS': 0,
#  'PATROLS': 0,
#  'REACHED': 0,
#  'WALL': 0,
#  'PLANNED': 0,
#  'SWING': 0,
#  'ORDER': 0,
#  'ENTER': 0,
#  'EASTWEST': 0,
#  'AUTOBAHN': 0,
#  'LEADING': 0,
#  'SECTOR': 0,
#  'CITY': 0,
#  'EN': 0,
#  'ROUTE': 0,
#  'RADIATOR': 0,
#  'FROZE': 0,
#  'SUBZERO': 0,
#  'WEATHER': 0,
#  'FIXED': 0,
#  'FEW': 0,
#  'TIRE': 0,
#  'BLEW': 0,
#  'KIDS': 0,
#  'CRYING': 0,
#  'SHIVERING': 0,
#  'COLD': 0,
#  'PANIC': 0,
#  'ARRIVED': 0,
#  'DREWITZ': 0,
#  'HEAVILY': 0,
#  'GUARDED': 0,
#  'CHECKPOINT': 0,
#  'ENTIRE': 0,
#  'RECONSIDER': 0,
#  'FLYING': 0,
#  'WAHAH': 0,
#  'SHRIEKED': 0,
#  'POLICETYPE': 0,
#  'KLAXONS': 0,
#  'THOUGHTFULLY': 0,
#  'INSTALLED': 0,
#  'ADVANCE': 0,
#  'GUARDS': 0,
#  'OBEDIENTLY': 0,
#  'RAISED': 0,
#  'BARRIERS': 0,
#  'DOING': 0,
#  'EMERGENCY': 0,
#  'DUTY': 0,
#  'SUDDENLY': 0,
#  'SHOOTING': 0,
#  'LATE': 0,
#  'MPH': 0,
#  'CRASHING': 0,
#  'THROUGH': 0,
#  'SECOND': 0,
#  'BARRIER': 0,
#  'YARDS': 0,
#  'THIRD': 0,
#  'WINDSHIELD': 0,
#  'SMASHED': 0,
#  'PASSENGERS': 0,
#  'SHAKEN': 0,
#  'CARGO': 0,
#  'EVERY': 0,
#  'CORNER': 0,
#  'CAB': 0,
#  'FINALLY': 0,
#  'LURCHED': 0,
#  'DOWN': 0,
#  'ROAD': 0,
#  'WHERE': 0,
#  'COMMUNISTS': 0,
#  'LONGER': 0,
#  'MATTERED': 0,
#  'FOOT': 0,
#  'JAIL': 0,
#  'PAVED': 0,
#  'NONOBJECTIVE': 0,
#  'ART': 0,
#  'SINCE': 0,
#  'KREMLINS': 0,
#  'SHARPEST': 0,
#  'BARBS': 0,
#  'THESE': 0,
#  'MODERN': 0,
#  'ESPIONAGE': 0,
#  'MATTER': 0,
#  'KGBS': 0,
#  'COPS': 0,
#  'TURN': 0,
#  'VICTIM': 0,
#  'WHOSE': 0,
#  'WRONGDOINGS': 0,
#  'COMBINED': 0,
#  'BOTH': 0,
#  'EVILS': 0,
#  'TURNED': 0,
#  'LENINGRAD': 0,
#  'PHYSICS': 0,
#  'TEACHER': 0,
#  'TASTE': 0,
#  'ABSTRACT': 0,
#  'PAINTING': 0,
#  'ALLEGEDLY': 0,
#  'LED': 0,
#  'JOIN': 0,
#  'SPY': 0,
#  'POLICE': 0,
#  'SPOTTED': 0,
#  'RUDOLF': 0,
#  'FRIEDMAN': 0,
#  'MUTTERED': 0,
#  'UNCOMPLIMENTARY': 0,
#  'REMARKS': 0,
#  'ABOUT': 0,
#  'SOCIALIST': 0,
#  'REALISM': 0,
#  'WHILE': 0,
#  'STROLLING': 0,
#  'LENINGRADS': 0,
#  'RUSSIAN': 0,
#  'MUSEUM': 0,
#  'WELLDRESSED': 0,
#  'TOURIST': 0,
#  'APPROACHED': 0,
#  'ENTHUSIASTICALLY': 0,
#  'SHARED': 0,
#  'SENTIMENTS': 0,
#  'SEND': 0,
#  'REPRODUCTIONS': 0,
#  'AVANTGARDE': 0,
#  'PAINTINGS': 0,
#  'AMERICA': 0,
#  'PICTURE': 0,
#  'LIKED': 0,
#  'INDIGNANTLY': 0,
#  'CHAOS': 0,
#  'BLACK': 0,
#  'RED': 0,
#  'BLUE': 0,
#  'SPLOTCHES': 0,
#  'CAPTIONED': 0,
#  'I': 0,
#  'NEED': 0,
#  'YOU': 0,
#  'TONIGHT': 0,
#  'SOON': 0,
#  'GETTING': 0,
#  'MESSAGES': 0,
#  'WRITTEN': 0,
#  'INVISIBLE': 0,
#  'INK': 0,
#  'PREPARED': 0,
#  'DELIVER': 0,
#  'INFORMATION': 0,
#  'REMOTE': 0,
#  'THEORETICAL': 0,
#  'ARGUMENTS': 0,
#  'POLICEMOVED': 0,
#  'HUSTLED': 0,
#  'CONGO': 0,
#  'ROUND': 0,
#  'SOUND': 0,
#  'KATANGA': 0,
#  'PROVINCE': 0,
#  'THUNK': 0,
#  'MORTAR': 0,
#  'SHELLS': 0,
#  'RATTLE': 0,
#  'MACHINE': 0,
#  'GUNS': 0,
#  'UNEASY': 0,
#  'TWELVEMONTH': 0,
#  'TRUCE': 0,
#  'UN': 0,
#  'TROOPS': 0,
#  'KATANGAS': 0,
#  'SECESSIONIST': 0,
#  'MOISE': 0,
#  'TSHOMBE': 0,
#  'MINOR': 0,
#  'INCIDENTS': 0,
#  'SEPTEMBER': 0,
#  'TURMOIL': 0,
#  'BLUEHELMETED': 0,
#  'SOLDIERS': 0,
#  'SWARMED': 0,
#  'ELISABETHVILLE': 0,
#  'SEIZED': 0,
#  'HIGHWAYS': 0,
#  'SWEDISH': 0,
#  'SAAB': 0,
#  'JETS': 0,
#  'SWOOPED': 0,
#  'LOW': 0,
#  'AIRFIELD': 0,
#  'KOLWEZI': 0,
#  'DESTROYING': 0,
#  'PLANES': 0,
#  'SETTING': 0,
#  'OIL': 0,
#  'TANKS': 0,
#  'ABLAZE': 0,
#  'SKIRMISHES': 0,
#  'SEVEN': 0,
#  'DEAD': 0,
#  'FIGHTING': 0,
#  'RESIDENTS': 0,
#  'LAFFAIRE': 0,
#  'SIMBA': 0,
#  'REFERENCE': 0,
#  'BEER': 0,
#  'BREW': 0,
#  'SIDES': 0,
#  'GUZZLED': 0,
#  'BOOZEDUP': 0,
#  'KATANGESE': 0,
#  'GENDARMES': 0,
#  'OPENED': 0,
#  'FIRE': 0,
#  'DETACHMENT': 0,
#  'ETHIOPIAN': 0,
#  'SUBURBAN': 0,
#  'LUBUMBASHI': 0,
#  'DESCRIBED': 0,
#  'MATTERS': 0,
#  'TIPSY': 0,
#  'ETHIOPIANS': 0,
#  'STARTED': 0,
#  'SCRAMBLING': 0,
#  'ATOP': 0,
#  'FT': 0,
#  'SLAG': 0,
#  'HEAP': 0,
#  'OUTSIDE': 0,
#  'BIG': 0,
#  'UNION': 0,
#  'MINIERE': 0,
#  'TAKING': 0,
#  'POTSHOTS': 0,
#  'FIREWORKS': 0,
#  'NEXT': 0,
#  'GOLF': 0,
#  'COURSE': 0,
#  'OUTSKIRTS': 0,
#  'TOOK': 0,
#  'OCCASION': 0,
#  'SHOOT': 0,
#  'UNARMED': 0,
#  'HELICOPTER': 0,
#  'MOVING': 0,
#  'OVERHEAD': 0,
#  'STONED': 0,
#  'SURVIVING': 0,
#  'CREWMEN': 0,
#  'PUMMELED': 0,
#  'RIFLE': 0,
#  'BUTTS': 0,
#  'YEAROLD': 0,
#  'SIKH': 0,
#  'LIEUTENANT': 0,
#  'LAY': 0,
#  'HELPLESS': 0,
#  'GUN': 0,
#  'SLUG': 0,
#  'ABDOMEN': 0,
#  'DIED': 0,
#  'UNATTENDED': 0,
#  'HOURS': 0,
#  'INDIAN': 0,
#  'BRIGADIER': 0,
#  'REGINALD': 0,
#  'NORONHA': 0,
#  'COMMANDER': 0,
#  'CAPITAL': 0,
#  'FURIOUS': 0,
#  'GOING': 0,
#  'WAIT': 0,
#  'LATER': 0,
#  'GUARD': 0,
#  'WARNING': 0,
#  'SHOT': 0,
#  'SOLDIER': 0,
#  'APPROACHING': 0,
#  'UNHURT': 0,
#  'ROLLED': 0,
#  'HILL': 0,
#  'SEARCH': 0,
#  'COVER': 0,
#  'COMRADES': 0,
#  'THOUGHT': 0,
#  'HIT': 0,
#  'POSITIONS': 0,
#  'AROUND': 0,
#  'UNDER': 0,
#  'AGREED': 0,
#  'CEASEFIRE': 0,
#  'MEN': 0,
#  'KEPT': 0,
#  'RIGHT': 0,
#  'MAD': 0,
#  'CROSS': 0,
#  'RAMPAGING': 0,
#  'TOWNSHIP': 0,
#  'FIRING': 0,
#  'ANYTHING': 0,
#  'MOVED': 0,
#  'KILLING': 0,
#  'CLAIMED': 0,
#  'LOST': 0,
#  'GAVE': 0,
#  'EXCUSE': 0,
#  'MANHATTAN': 0,
#  'HEADQUARTERS': 0,
#  'ORDERS': 0,
#  'FLASHED': 0,
#  'MAN': 0,
#  'NECESSARY': 0,
#  'ACTION': 0,
#  'SELFDEFENSE': 0,
#  'RESTORE': 0,
#  'SPEARHEADED': 0,
#  'TOUGH': 0,
#  'GURKHAS': 0,
#  'METHODICALLY': 0,
#  'SWEPT': 0,
#  'DISORGANIZED': 0,
#  'GUARDPOSTS': 0,
#  'NORTHERN': 0,
#  'RHODESIA': 0,
#  'LINES': 0,
#  'FELL': 0,
#  'FRAY': 0,
#  'LEAVING': 0,
#  'SHABBY': 0,
#  'POP': 0,
#  'LIGHT': 0,
#  'WATER': 0,
#  'PHONES': 0,
#  'SPEARS': 0,
#  'ARROWS': 0,
#  'DEMANDED': 0,
#  'ONCE': 0,
#  'WARNED': 0,
#  'UNLESS': 0,
#  'COMPLIED': 0,
#  'MINUTES': 0,
#  'GENERAL': 0,
#  'WAR': 0,
#  'BEGIN': 0,
#  'REJECTED': 0,
#  'ULTIMATUM': 0,
#  'ALLOUT': 0,
#  'AIR': 0,
#  'OFFENSIVE': 0,
#  'BRIGADE': 0,
#  'STORMED': 0,
#  'CAPTURED': 0,
#  'GENDARMERIE': 0,
#  'KARAVIA': 0,
#  'MILE': 0,
#  'RESISTANCE': 0,
#  'ANOTHER': 0,
#  'COLUMN': 0,
#  'NORTHWEST': 0,
#  'JADOTVILLE': 0,
#  'HEART': 0,
#  'COPPER': 0,
#  'BELT': 0,
#  'GIVES': 0,
#  'REVENUES': 0,
#  'ANNOUNCED': 0,
#  'TAKEN': 0,
#  'ELISABETHVILLES': 0,
#  'OFFICE': 0,
#  ...}

# %%
show_document_vector(vectors, 0)
# Out:
# POLARIS:	23.375253845608476	(normalized: 0.23610685962782985)
# NUCLEAR:	22.63182545128017	(normalized: 0.2285976986705899)
# DE:	19.326040116876754	(normalized: 0.19520689149198198)
# OFFER:	16.735653846148775	(normalized: 0.16904212889114578)
# NASSAU:	16.40584811996386	(normalized: 0.16571085408184888)
# GAULLE:	15.088863166549562	(normalized: 0.1524083597610793)
# NATO:	14.00280067405182	(normalized: 0.1414383482199473)
# FORCE:	13.730252417975137	(normalized: 0.13868541499987036)
# DETERRENT:	13.633259397724078	(normalized: 0.13770571580308075)
# SKYBOLT:	13.313802799836534	(normalized: 0.13447897462573138)
# GOITALONE:	12.094744358092555	(normalized: 0.1221656084358262)
# FRAPPE:	11.550442805130174	(normalized: 0.11666777165470212)
# BRITAINS:	11.425424715928472	(normalized: 0.11540499912469891)
# MACMILLAN:	11.31398541671231	(normalized: 0.11427938213029792)
# US:	11.311010314826785	(normalized: 0.11424933146355849)
# BRITAIN:	10.911150665198967	(normalized: 0.11021046169174444)
# FLEET:	10.860670675484297	(normalized: 0.10970057752431259)
# ARSENAL:	10.708449996972666	(normalized: 0.10816303929644215)
# FRANCES:	10.453539898244527	(normalized: 0.10558826413910506)
# INTERESTS:	10.22494454829306	(normalized: 0.10327928685231057)
# BOMBER:	9.897519780756337	(normalized: 0.09997206143614715)
# KENNEDY:	9.33520044936788	(normalized: 0.09429223214663154)
# OBSOLETE:	9.322155635852775	(normalized: 0.09416047015705808)
# ADENAUER:	9.15491971647686	(normalized: 0.09247126720757916)
# FRANCE:	8.51783378596297	(normalized: 0.08603624154496084)
# GRANDEUR:	8.511225419636446	(normalized: 0.08596949229676308)
# WILL:	8.460455124977603	(normalized: 0.0854566758408027)
# CONVENTIONAL:	8.20292405998193	(normalized: 0.08285542704092444)
# DEVELOP:	7.9358612747328845	(normalized: 0.080157901017674)
# SUBMARINES:	7.9358612747328845	(normalized: 0.080157901017674)
# MULTILATERAL:	7.9358612747328845	(normalized: 0.080157901017674)
# FRENCH:	7.79367904657069	(normalized: 0.07872175835124602)
# ALLIED:	7.298953812495815	(normalized: 0.07372467801288611)
# MISSILE:	6.678643955888136	(normalized: 0.06745910275080852)
# NOTHING:	6.656192347671549	(normalized: 0.06723232537569956)
# STRATEGIC:	6.103279810984573	(normalized: 0.061647511471719436)
# THUS:	6.066061464933386	(normalized: 0.061271579434158334)
# OUTLINES:	6.0473721790462776	(normalized: 0.0610828042179131)
# SPRANG:	6.0473721790462776	(normalized: 0.0610828042179131)
# ANGLOUS:	6.0473721790462776	(normalized: 0.0610828042179131)
# UNRESERVEDLY:	6.0473721790462776	(normalized: 0.0610828042179131)
# MISSILEPACKING:	6.0473721790462776	(normalized: 0.0610828042179131)
# STIPULATES:	6.0473721790462776	(normalized: 0.0610828042179131)
# CARTOONISTS:	6.0473721790462776	(normalized: 0.0610828042179131)
# SUPERMAC:	6.0473721790462776	(normalized: 0.0610828042179131)
# SUPERJACKS:	6.0473721790462776	(normalized: 0.0610828042179131)
# EDITH:	6.0473721790462776	(normalized: 0.0610828042179131)
# VINDICATED:	6.0473721790462776	(normalized: 0.0610828042179131)
# DEVASTATION:	6.0473721790462776	(normalized: 0.0610828042179131)
# NONCOMMITTALLY:	6.0473721790462776	(normalized: 0.0610828042179131)
# HAUTEUR:	6.0473721790462776	(normalized: 0.0610828042179131)
# THREENATION:	6.0473721790462776	(normalized: 0.0610828042179131)
# RELIANCE:	6.0473721790462776	(normalized: 0.0610828042179131)
# KNIGHTS:	6.0473721790462776	(normalized: 0.0610828042179131)
# FROSTY:	6.0473721790462776	(normalized: 0.0610828042179131)
# CREDIBLE:	6.0473721790462776	(normalized: 0.0610828042179131)
# NUISANCE:	6.0473721790462776	(normalized: 0.0610828042179131)
# PEA:	6.0473721790462776	(normalized: 0.0610828042179131)
# MINUTEMAN:	6.0473721790462776	(normalized: 0.0610828042179131)
# EVENTUALLY:	5.912659451375924	(normalized: 0.05972210887350204)
# EUROPE:	5.7607133820035585	(normalized: 0.05818734439525268)
# GERMANY:	5.665467287059818	(normalized: 0.05722529039928269)
# BRITISH:	5.650572763266569	(normalized: 0.057074845006830334)
# HELP:	5.618954727451922	(normalized: 0.056755480126641056)
# EXCEPT:	5.430335337742148	(normalized: 0.05485028876215629)
# DEVISE:	5.354224998486333	(normalized: 0.054081519648221076)
# BUGRIDDEN:	5.354224998486333	(normalized: 0.054081519648221076)
# JUSTIFY:	5.354224998486333	(normalized: 0.054081519648221076)
# DOWNGRADE:	5.354224998486333	(normalized: 0.054081519648221076)
# PRIZED:	5.354224998486333	(normalized: 0.054081519648221076)
# CROW:	5.354224998486333	(normalized: 0.054081519648221076)
# BRAGGED:	5.354224998486333	(normalized: 0.054081519648221076)
# UNSWERVING:	5.354224998486333	(normalized: 0.054081519648221076)
# INVADE:	5.354224998486333	(normalized: 0.054081519648221076)
# INVITE:	5.354224998486333	(normalized: 0.054081519648221076)
# TRIUMVIRATE:	5.354224998486333	(normalized: 0.054081519648221076)
# UNSPOKEN:	5.354224998486333	(normalized: 0.054081519648221076)
# DIRECTORATE:	5.354224998486333	(normalized: 0.054081519648221076)
# MANUFACTURE:	5.354224998486333	(normalized: 0.054081519648221076)
# APPREHENSIVE:	5.354224998486333	(normalized: 0.054081519648221076)
# FODDER:	5.354224998486333	(normalized: 0.054081519648221076)
# INDEPENDENTLY:	5.354224998486333	(normalized: 0.054081519648221076)
# BAIL:	5.354224998486333	(normalized: 0.054081519648221076)
# THROWS:	5.354224998486333	(normalized: 0.054081519648221076)
# NATOCONTROLLED:	5.354224998486333	(normalized: 0.054081519648221076)
# SPIRALING:	5.354224998486333	(normalized: 0.054081519648221076)
# STRIKE:	5.2267699491222634	(normalized: 0.05279413206955253)
# COST:	5.2267699491222634	(normalized: 0.05279413206955253)
# ALLIANCE:	5.2267699491222634	(normalized: 0.05279413206955253)
# ALLIES:	5.042023308860233	(normalized: 0.050928058257171005)
# CANCELLATION:	4.948759890378168	(normalized: 0.049986030718073574)
# INCLUSION:	4.948759890378168	(normalized: 0.049986030718073574)
# PLOY:	4.948759890378168	(normalized: 0.049986030718073574)
# JUMPING:	4.948759890378168	(normalized: 0.049986030718073574)
# DEVELOPING:	4.948759890378168	(normalized: 0.049986030718073574)
# HUMILIATION:	4.948759890378168	(normalized: 0.049986030718073574)
# FIASCO:	4.948759890378168	(normalized: 0.049986030718073574)
# REFLECT:	4.948759890378168	(normalized: 0.049986030718073574)
# SNAP:	4.948759890378168	(normalized: 0.049986030718073574)
# RELEGATED:	4.948759890378168	(normalized: 0.049986030718073574)
# SECONDCLASS:	4.948759890378168	(normalized: 0.049986030718073574)
# DEVASTATING:	4.948759890378168	(normalized: 0.049986030718073574)
# WEAPONS:	4.872908532804107	(normalized: 0.04921987750520981)
# GROUND:	4.819572038639785	(normalized: 0.048681140590356484)
# EXPECTED:	4.767621065833263	(normalized: 0.04815639843675361)
# SUGGESTED:	4.7169854498646835	(normalized: 0.04764494233233538)
# INTERVENE:	4.661077817926388	(normalized: 0.04708023507852904)
# VAUNTED:	4.661077817926388	(normalized: 0.04708023507852904)
# CITIZENSHIP:	4.661077817926388	(normalized: 0.04708023507852904)
# BULLETIN:	4.661077817926388	(normalized: 0.04708023507852904)
# REVIVED:	4.661077817926388	(normalized: 0.04708023507852904)
# INTEND:	4.661077817926388	(normalized: 0.04708023507852904)
# PLANNERS:	4.661077817926388	(normalized: 0.04708023507852904)
# INVITING:	4.661077817926388	(normalized: 0.04708023507852904)
# RUSSIANS:	4.572344126705431	(normalized: 0.04618396103950714)
# DOES:	4.481419378551917	(normalized: 0.04526555575112946)
# ACCORD:	4.437934266612178	(normalized: 0.044826324875243795)
# BEAMED:	4.437934266612178	(normalized: 0.044826324875243795)
# BACKBENCHERS:	4.437934266612178	(normalized: 0.044826324875243795)
# LIKELIHOOD:	4.437934266612178	(normalized: 0.044826324875243795)
# CONVICTION:	4.437934266612178	(normalized: 0.044826324875243795)
# DIVISIONS:	4.437934266612178	(normalized: 0.044826324875243795)
# MILITARILY:	4.437934266612178	(normalized: 0.044826324875243795)
# WHETHER:	4.311103761871303	(normalized: 0.043545245646022655)
# EMERGING:	4.255612709818223	(normalized: 0.04298474614838154)
# NECK:	4.255612709818223	(normalized: 0.04298474614838154)
# LOUDLY:	4.255612709818223	(normalized: 0.04298474614838154)
# TRULY:	4.255612709818223	(normalized: 0.04298474614838154)
# DELIBERATE:	4.255612709818223	(normalized: 0.04298474614838154)
# RELATIONSHIP:	4.255612709818223	(normalized: 0.04298474614838154)
# EFFICIENTLY:	4.255612709818223	(normalized: 0.04298474614838154)
# CANNON:	4.255612709818223	(normalized: 0.04298474614838154)
# DAMNED:	4.255612709818223	(normalized: 0.04298474614838154)
# DIMINISHING:	4.255612709818223	(normalized: 0.04298474614838154)
# CHARLES:	4.192256920929701	(normalized: 0.042344807157664525)
# NATIONAL:	4.180235486666263	(normalized: 0.04222338203386011)
# SYSTEMS:	4.101462029990965	(normalized: 0.04142771352046222)
# POINTEDLY:	4.101462029990965	(normalized: 0.04142771352046222)
# TECHNOLOGY:	4.101462029990965	(normalized: 0.04142771352046222)
# VOWED:	4.101462029990965	(normalized: 0.04142771352046222)
# PLEAS:	4.101462029990965	(normalized: 0.04142771352046222)
# RAISING:	4.101462029990965	(normalized: 0.04142771352046222)
# CAPACITY:	4.101462029990965	(normalized: 0.04142771352046222)
# VALUE:	4.101462029990965	(normalized: 0.04142771352046222)
# STUDIED:	3.9679306373664422	(normalized: 0.040078950508837)
# SUPREME:	3.9679306373664422	(normalized: 0.040078950508837)
# DELIVERY:	3.9679306373664422	(normalized: 0.040078950508837)
# RETALIATION:	3.9679306373664422	(normalized: 0.040078950508837)
# REPRESENTS:	3.9679306373664422	(normalized: 0.040078950508837)
# DEC:	3.8501476017100584	(normalized: 0.03888925721823404)
# WEAPON:	3.8501476017100584	(normalized: 0.03888925721823404)
# TYPE:	3.8501476017100584	(normalized: 0.03888925721823404)
# SUBMARINE:	3.8501476017100584	(normalized: 0.03888925721823404)
# JACK:	3.8501476017100584	(normalized: 0.03888925721823404)
# EASE:	3.8501476017100584	(normalized: 0.03888925721823404)
# BECOMES:	3.8501476017100584	(normalized: 0.03888925721823404)
# OWN:	3.8391033752555757	(normalized: 0.038777702595451775)
# BECOME:	3.776978191373212	(normalized: 0.03815019359952179)
# PACT:	3.744787086052232	(normalized: 0.037825040305551755)
# FARTHER:	3.744787086052232	(normalized: 0.037825040305551755)
# COMMANDS:	3.744787086052232	(normalized: 0.037825040305551755)
# HELPING:	3.744787086052232	(normalized: 0.037825040305551755)
# DISCUSS:	3.744787086052232	(normalized: 0.037825040305551755)
# GUEST:	3.744787086052232	(normalized: 0.037825040305551755)
# WARFARE:	3.744787086052232	(normalized: 0.037825040305551755)
# WOULD:	3.7081593005510234	(normalized: 0.03745507335388005)
# SAVED:	3.6494769062479073	(normalized: 0.036862339006443055)
# SHOULDER:	3.6494769062479073	(normalized: 0.036862339006443055)
# DESIGN:	3.6494769062479073	(normalized: 0.036862339006443055)
# SKEPTICAL:	3.6494769062479073	(normalized: 0.036862339006443055)
# PLEDGED:	3.6494769062479073	(normalized: 0.036862339006443055)
# THOUGH:	3.6332708162844	(normalized: 0.03669864585327336)
# WELCOMED:	3.5624655292582776	(normalized: 0.03598346157868951)
# ENTRY:	3.5624655292582776	(normalized: 0.03598346157868951)
# FEARFUL:	3.5624655292582776	(normalized: 0.03598346157868951)
# GOAL:	3.5624655292582776	(normalized: 0.03598346157868951)
# CRY:	3.5624655292582776	(normalized: 0.03598346157868951)
# IF:	3.5532675193269956	(normalized: 0.03589055506935084)
# GENERATION:	3.4824228215847413	(normalized: 0.03517497271821633)
# INCLUDE:	3.4824228215847413	(normalized: 0.03517497271821633)
# ADVANCED:	3.4824228215847413	(normalized: 0.03517497271821633)
# ATOMIC:	3.4824228215847413	(normalized: 0.03517497271821633)
# ITS:	3.433808821427182	(normalized: 0.03468393638607808)
# DECEMBER:	3.4083148494310196	(normalized: 0.03442642895077019)
# SPEND:	3.4083148494310196	(normalized: 0.03442642895077019)
# TIES:	3.4083148494310196	(normalized: 0.03442642895077019)
# CONTRAST:	3.4083148494310196	(normalized: 0.03442642895077019)
# MEANING:	3.4083148494310196	(normalized: 0.03442642895077019)
# COULD:	3.3955005911218086	(normalized: 0.034296995734436744)
# ALREADY:	3.355848653158513	(normalized: 0.03389648266995809)
# BRITONS:	3.339321977944068	(normalized: 0.03372955137540426)
# DECIDE:	3.339321977944068	(normalized: 0.03372955137540426)
# CONFLICT:	3.339321977944068	(normalized: 0.03372955137540426)
# QUICK:	3.339321977944068	(normalized: 0.03372955137540426)
# BOMBS:	3.339321977944068	(normalized: 0.03372955137540426)
# SUBJECT:	3.339321977944068	(normalized: 0.03372955137540426)
# DIRECTLY:	3.339321977944068	(normalized: 0.03372955137540426)
# SUPPLIES:	3.339321977944068	(normalized: 0.03372955137540426)
# FIRST:	3.3297456857491694	(normalized: 0.03363282394339647)
# PRIME:	3.3058460487476786	(normalized: 0.03339142043710996)
# MEAN:	3.274783456806497	(normalized: 0.03307766593914497)
# EQUAL:	3.274783456806497	(normalized: 0.03307766593914497)
# CREATE:	3.274783456806497	(normalized: 0.03307766593914497)
# LEAST:	3.2570631424993604	(normalized: 0.03289867803209119)
# WITHDRAWAL:	3.214158834990062	(normalized: 0.03246531369827754)
# UNLIKE:	3.214158834990062	(normalized: 0.03246531369827754)
# RESPONSIBLE:	3.214158834990062	(normalized: 0.03246531369827754)
# AIMED:	3.214158834990062	(normalized: 0.03246531369827754)
# LETTER:	3.214158834990062	(normalized: 0.03246531369827754)
# KEEPING:	3.1570004211501135	(normalized: 0.03188797264854201)
# SEPARATE:	3.1570004211501135	(normalized: 0.03188797264854201)
# PARTICULARLY:	3.1570004211501135	(normalized: 0.03188797264854201)
# CONDITIONS:	3.1570004211501135	(normalized: 0.03188797264854201)
# AGREE:	3.1570004211501135	(normalized: 0.03188797264854201)
# MILLION:	3.1400707291361427	(normalized: 0.0317169705947339)
# WESTERN:	3.1400707291361427	(normalized: 0.0317169705947339)
# SOVIET:	3.1400707291361427	(normalized: 0.0317169705947339)
# COMMITTED:	3.1029331998798377	(normalized: 0.03134185486487028)
# KONRAD:	3.1029331998798377	(normalized: 0.03134185486487028)
# WITHOUT:	3.095125017432026	(normalized: 0.03126298661174539)
# ATLANTIC:	3.0516399054922867	(normalized: 0.030823755735859718)
# MEMBERSHIP:	3.0516399054922867	(normalized: 0.030823755735859718)
# RAISE:	3.0516399054922867	(normalized: 0.030823755735859718)
# EFFORTS:	3.0516399054922867	(normalized: 0.030823755735859718)
# MAKES:	3.0516399054922867	(normalized: 0.030823755735859718)
# OFFICIAL:	3.051167203994475	(normalized: 0.030818981111082302)
# NO:	3.024772342622422	(normalized: 0.03055237404576317)
# SAW:	3.002849741322855	(normalized: 0.030330940020622685)
# DEVELOPMENT:	3.002849741322855	(normalized: 0.030330940020622685)
# POURED:	3.002849741322855	(normalized: 0.030330940020622685)
# PROVE:	3.002849741322855	(normalized: 0.030330940020622685)
# ATTACKED:	3.002849741322855	(normalized: 0.030330940020622685)
# ACHIEVE:	3.002849741322855	(normalized: 0.030330940020622685)
# IMMEDIATE:	3.002849741322855	(normalized: 0.030330940020622685)
# SUCCESSOR:	3.002849741322855	(normalized: 0.030330940020622685)
# CENT:	2.9660479751568833	(normalized: 0.029959215739226795)
# EUROPEANS:	2.956329725687962	(normalized: 0.02986105443675102)
# PRESUMABLY:	2.956329725687962	(normalized: 0.02986105443675102)
# ARGUED:	2.956329725687962	(normalized: 0.02986105443675102)
# BILLION:	2.9118779631171283	(normalized: 0.029412059694925222)
# TORY:	2.9118779631171283	(normalized: 0.029412059694925222)
# OR:	2.897448799631479	(normalized: 0.02926631477595429)
# ONLY:	2.851308881211081	(normalized: 0.028800268447059723)
# DEPARTMENT:	2.8284963541780774	(normalized: 0.02856984553257448)
# SENSE:	2.8284963541780774	(normalized: 0.02856984553257448)
# PROPOSED:	2.789275641024796	(normalized: 0.0281736881485243)
# CHANCELLOR:	2.789275641024796	(normalized: 0.0281736881485243)
# PER:	2.786823657777509	(normalized: 0.028148921355906742)
# WELL:	2.7678661698684217	(normalized: 0.027957437106528715)
# BUILD:	2.751535313041949	(normalized: 0.02779248371839451)
# BACKED:	2.751535313041949	(normalized: 0.02779248371839451)
# SUPPLY:	2.715167668871074	(normalized: 0.027425144381078147)
# SHARE:	2.715167668871074	(normalized: 0.027425144381078147)
# GREATER:	2.715167668871074	(normalized: 0.027425144381078147)
# TERMS:	2.680076349059804	(normalized: 0.027070696836869277)
# SURE:	2.680076349059804	(normalized: 0.027070696836869277)
# NONE:	2.6461747973841225	(normalized: 0.026728266805712227)
# INCREASINGLY:	2.6461747973841225	(normalized: 0.026728266805712227)
# ANSWER:	2.6461747973841225	(normalized: 0.026728266805712227)
# GAULLES:	2.6133849745611317	(normalized: 0.026397066034776265)
# VAST:	2.6133849745611317	(normalized: 0.026397066034776265)
# MANAGED:	2.6133849745611317	(normalized: 0.026397066034776265)
# MEANS:	2.6133849745611317	(normalized: 0.026397066034776265)
# HAROLD:	2.5816362762465515	(normalized: 0.026076381369452933)
# STRONG:	2.5816362762465515	(normalized: 0.026076381369452933)
# ELSE:	2.5816362762465515	(normalized: 0.026076381369452933)
# PROVED:	2.5508646175797978	(normalized: 0.025765565506603524)
# BIGGEST:	2.5508646175797978	(normalized: 0.025765565506603524)
# DECISION:	2.5508646175797978	(normalized: 0.025765565506603524)
# STRENGTH:	2.5508646175797978	(normalized: 0.025765565506603524)
# ACCEPT:	2.5210116544301164	(normalized: 0.025464029128585502)
# ANYONE:	2.5210116544301164	(normalized: 0.025464029128585502)
# ATTEMPT:	2.4920241175568645	(normalized: 0.025171234177792906)
# WANTS:	2.463853240590168	(normalized: 0.024886688078849972)
# REPLIED:	2.463853240590168	(normalized: 0.024886688078849972)
# HARDLY:	2.463853240590168	(normalized: 0.024886688078849972)
# BITTER:	2.4364542664020536	(normalized: 0.024609938752604903)
# PERHAPS:	2.3584927249323417	(normalized: 0.02382247116616769)
# PROMISED:	2.3584927249323417	(normalized: 0.02382247116616769)
# REASON:	2.33380011234197	(normalized: 0.023573058036657886)
# ABLE:	2.3097025607629096	(normalized: 0.023329655450930648)
# SPECIAL:	2.3097025607629096	(normalized: 0.023329655450930648)
# BE:	2.3077632413519784	(normalized: 0.023310066931423887)
# SHOWED:	2.263182545128017	(normalized: 0.02285976986705899)
# PRESIDENT:	2.254782506436306	(normalized: 0.022774923440605107)
# FIND:	2.2407096892759584	(normalized: 0.02263277787556473)
# POSSIBLE:	2.2407096892759584	(normalized: 0.02263277787556473)
# CRISIS:	2.218730782557183	(normalized: 0.022410775125233186)
# BEST:	2.218730782557183	(normalized: 0.022410775125233186)
# ATTACK:	2.218730782557183	(normalized: 0.022410775125233186)
# PLAN:	2.1972245773362196	(normalized: 0.022193546999679067)
# ANY:	2.1830902428900343	(normalized: 0.0220507800658498)
# ACTUALLY:	2.176171168138387	(normalized: 0.02198089243930543)
# GERMAN:	2.176171168138387	(normalized: 0.02198089243930543)
# QUESTION:	2.135349173618132	(normalized: 0.021568560962882444)
# RUN:	2.135349173618132	(normalized: 0.021568560962882444)
# CALL:	2.0961284604648505	(normalized: 0.021172403578832263)
# MINISTER:	2.0868517462016376	(normalized: 0.02107870209918979)
# SAY:	2.0583881324820035	(normalized: 0.020791199148702474)
# USE:	2.0583881324820035	(normalized: 0.020791199148702474)
# USED:	2.0583881324820035	(normalized: 0.020791199148702474)
# EUROPEAN:	2.040038993813807	(normalized: 0.02060585966377374)
# SMALL:	2.0043209112117277	(normalized: 0.020245081365030743)
# POLICY:	2.0043209112117277	(normalized: 0.020245081365030743)
# HAND:	2.0043209112117277	(normalized: 0.020245081365030743)
# WHAT:	1.9695542920386224	(normalized: 0.019893913530574018)
# MAJOR:	1.9530276168241774	(normalized: 0.01972698223602019)
# MARKET:	1.9530276168241774	(normalized: 0.01972698223602019)
# HAS:	1.9220584945516603	(normalized: 0.019414171848869337)
# AFTER:	1.9206012227584774	(normalized: 0.019399452356666805)
# BROUGHT:	1.9202377940011863	(normalized: 0.01939578146508423)
# CASE:	1.9202377940011863	(normalized: 0.01939578146508423)
# FORCES:	1.9202377940011863	(normalized: 0.01939578146508423)
# YET:	1.9202377940011863	(normalized: 0.01939578146508423)
# VERY:	1.9042374526547452	(normalized: 0.019234166520783153)
# THOSE:	1.888489095686606	(normalized: 0.019075096799760896)
# COMMON:	1.8577174370198524	(normalized: 0.018764280936911487)
# MUST:	1.7988769369969189	(normalized: 0.018169949608100866)
# THIS:	1.7890011764417322	(normalized: 0.018070197330477596)
# ALL:	1.7662804510011227	(normalized: 0.017840701678037602)
# CONTROL:	1.7569127378978868	(normalized: 0.017746081044725633)
# NATION:	1.7569127378978868	(normalized: 0.017746081044725633)
# TOLD:	1.7569127378978868	(normalized: 0.017746081044725633)
# RUSSIA:	1.7569127378978868	(normalized: 0.017746081044725633)
# SUPPORT:	1.7298840655099674	(normalized: 0.017473072032734946)
# ALMOST:	1.716638838759947	(normalized: 0.017339285725486205)
# ALONG:	1.6906633523566863	(normalized: 0.017076914648684768)
# FACT:	1.6906633523566863	(normalized: 0.017076914648684768)
# OFFICIALS:	1.6779243265792565	(normalized: 0.016948241334979044)
# SAME:	1.6779243265792565	(normalized: 0.016948241334979044)
# ARE:	1.6753033586687747	(normalized: 0.016921767675842914)
# DEFENSE:	1.6653455443723963	(normalized: 0.016821186596475652)
# NOT:	1.6555863354975728	(normalized: 0.01672261157456976)
# NEVER:	1.6285315712496802	(normalized: 0.016449339016045596)
# OTHER:	1.6112503279732713	(normalized: 0.016274786041887243)
# WHICH:	1.5657577197434822	(normalized: 0.015815278011028677)
# WENT:	1.536512672529428	(normalized: 0.015519882020765445)
# LEADER:	1.5255836019972375	(normalized: 0.015409490555541151)
# GOOD:	1.5255836019972375	(normalized: 0.015409490555541151)
# UNTIL:	1.5147726858930222	(normalized: 0.015300292534936734)
# IT:	1.5084279123393283	(normalized: 0.015236205763143502)
# EVEN:	1.4981096249964827	(normalized: 0.01513198364699675)
# HAVE:	1.4824735071119846	(normalized: 0.014974047621366253)
# TIME:	1.4782089632901465	(normalized: 0.014930972664569211)
# GOT:	1.472661200542895	(normalized: 0.014874936274596063)
# THAT:	1.4602690539103629	(normalized: 0.014749766689496374)
# DO:	1.452252328911688	(normalized: 0.014668792006763992)
# TOO:	1.452252328911688	(normalized: 0.014668792006763992)
# ARMY:	1.4126431908166424	(normalized: 0.014268711251707583)
# POWER:	1.4126431908166424	(normalized: 0.014268711251707583)
# BETWEEN:	1.4029812799049053	(normalized: 0.01417111900914023)
# MAY:	1.3934118288887545	(normalized: 0.014074460677953371)
# THEY:	1.3803705619380855	(normalized: 0.01394273451122902)
# WHO:	1.3743588175603074	(normalized: 0.013882011573403507)
# WHEN:	1.369155595606264	(normalized: 0.013829455293004157)
# IS:	1.3461017979069558	(normalized: 0.013596595371429378)
# WAY:	1.3378419777339439	(normalized: 0.01351316525276537)
# LONG:	1.2766875545806133	(normalized: 0.012895461637717912)
# STATE:	1.2682486859347486	(normalized: 0.012810223000826652)
# GOVERNMENT:	1.2625435536837155	(normalized: 0.01275259706579083)
# SAID:	1.253674359547984	(normalized: 0.012663011832250765)
# END:	1.2515816334495369	(normalized: 0.012641873794973005)
# JUST:	1.2351878236738605	(normalized: 0.012476284536818354)
# LITTLE:	1.2270906134412412	(normalized: 0.012394496895392196)
# OLD:	1.2110902720948	(normalized: 0.012232881951091118)
# MADE:	1.1798377285906956	(normalized: 0.011917208805854985)
# COUNTRY:	1.1798377285906956	(normalized: 0.011917208805854985)
# WERE:	1.1665198618374635	(normalized: 0.011782688782379893)
# WEST:	1.1645702564599072	(normalized: 0.011762996367219456)
# INTO:	1.1502030107496064	(normalized: 0.011617876862269231)
# MANY:	1.127391253218153	(normalized: 0.011387461720302553)
# HIS:	1.085424732677887	(normalized: 0.010963569708702837)
# BEFORE:	1.0434258731008188	(normalized: 0.010539351049594895)
# BACK:	1.0300923422313535	(normalized: 0.010404672807290733)
# MORE:	1.0279653806375153	(normalized: 0.010383188966910343)
# THEN:	0.99112637369797	(normalized: 0.010011088526942801)
# AT:	0.9509653242803818	(normalized: 0.009605433070964672)
# THEIR:	0.9420927064455977	(normalized: 0.00951581325560415)
# AGAINST:	0.9353843906897348	(normalized: 0.009448054446353561)
# WE:	0.9293783666295229	(normalized: 0.009387389287845679)
# HAD:	0.8748898963780976	(normalized: 0.008837016586784919)
# NOW:	0.8655886287541927	(normalized: 0.008743067100557169)
# SO:	0.8599863732055231	(normalized: 0.008686480294135065)
# THREE:	0.8599863732055231	(normalized: 0.008686480294135065)
# THEM:	0.8599863732055231	(normalized: 0.008686480294135065)
# BY:	0.8520619859502464	(normalized: 0.00860643828895831)
# FROM:	0.8481819863331945	(normalized: 0.008567247504935597)
# MOST:	0.714653385780909	(normalized: 0.00721851269524616)
# ONE:	0.7005573850817469	(normalized: 0.00707613295980572)
# YEARS:	0.6674748255058185	(normalized: 0.006741975337325376)
# AS:	0.6673567705823108	(normalized: 0.006740782897772116)
# OVER:	0.6583004492297772	(normalized: 0.0066493075448861025)
# THERE:	0.6446947971739986	(normalized: 0.006511880683073334)
# WITH:	0.5478913131612483	(normalized: 0.005534095938477833)
# AN:	0.5332573265078973	(normalized: 0.005386282158341819)
# BEEN:	0.4752181468685135	(normalized: 0.00480004474117662)
# WEEK:	0.4671839016615207	(normalized: 0.004718893091751457)
# HE:	0.46648329444242315	(normalized: 0.0047118164554322845)
# BUT:	0.4506549342286122	(normalized: 0.004551938644144126)
# OUT:	0.41975106535564094	(normalized: 0.004239787363215115)
# UP:	0.4054651081081644	(normalized: 0.004095488930147497)
# WAS:	0.3973487594625282	(normalized: 0.004013507976998371)
# LAST:	0.38691850583420445	(normalized: 0.003908154920917315)
# ON:	0.38691850583420445	(normalized: 0.003908154920917315)
# FOR:	0.15274927052463683	(normalized: 0.0015428773870102554)
# AND:	0.11387948430182328	(normalized: 0.0011502646171088172)
# TO:	0.06390535527718859	(normalized: 0.0006454900061216852)
# IN:	0.02366865010266244	(normalized: 0.00023907037263766118)

# %%
vectors[3]
# Out:
# {'THE': 0.0,
#  'ALLIES': 0,
#  'AFTER': 0,
#  'NASSAU': 0,
#  'IN': 0.004733730020532488,
#  'DECEMBER': 0,
#  'US': 2.2622020629653568,
#  'FIRST': 0.8324364214372924,
#  'PROPOSED': 0,
#  'TO': 0.014201190061597466,
#  'HELP': 0,
#  'NATO': 0,
#  'DEVELOP': 0,
#  'ITS': 0,
#  'OWN': 0,
#  'NUCLEAR': 0,
#  'STRIKE': 0,
#  'FORCE': 0,
#  'BUT': 0,
#  'EUROPE': 0,
#  'MADE': 0,
#  'NO': 0,
#  'ATTEMPT': 0,
#  'DEVISE': 0,
#  'A': 0.0,
#  'PLAN': 0,
#  'LAST': 0,
#  'WEEK': 0,
#  'AS': 0.3336783852911554,
#  'THEY': 0.920247041292057,
#  'STUDIED': 0,
#  'ACCORD': 0,
#  'BETWEEN': 0,
#  'PRESIDENT': 0,
#  'KENNEDY': 0,
#  'AND': 0.02846987107545582,
#  'PRIME': 0,
#  'MINISTER': 0,
#  'MACMILLAN': 0,
#  'EUROPEANS': 0,
#  'SAW': 0,
#  'EMERGING': 0,
#  'OUTLINES': 0,
#  'OF': 0.0,
#  'THAT': 0,
#  'WANTS': 0,
#  'WILL': 0,
#  'SUPPORT': 0,
#  'IT': 0.2154897017627612,
#  'ALL': 0,
#  'SPRANG': 0,
#  'FROM': 0.5089091917999167,
#  'ANGLOUS': 0,
#  'CRISIS': 0,
#  'OVER': 0,
#  'CANCELLATION': 0,
#  'BUGRIDDEN': 0,
#  'SKYBOLT': 0,
#  'MISSILE': 0,
#  'OFFER': 0,
#  'SUPPLY': 0,
#  'BRITAIN': 0,
#  'FRANCE': 0,
#  'WITH': 0.06848641414515604,
#  'PROVED': 0,
#  'POLARIS': 0,
#  'TIME': 0.7391044816450733,
#  'DEC': 0,
#  'ONE': 0.35027869254087346,
#  'ALLIED': 0,
#  'LEADER': 0,
#  'WHO': 0,
#  'UNRESERVEDLY': 0,
#  'WELCOMED': 0,
#  'WAS': 0.2980115695968961,
#  'HAROLD': 0,
#  'BY': 0,
#  'THUS': 0,
#  'KEEPING': 0,
#  'SEPARATE': 0,
#  'DETERRENT': 0,
#  'FOR': 0.019093658815579603,
#  'HAD': 0,
#  'SAVED': 0,
#  'HIS': 0.18090412211298115,
#  'NECK': 0,
#  'BACK': 0,
#  'BEAMED': 0,
#  'NOW': 0,
#  'WEAPON': 0,
#  'GENERATION': 0,
#  'TERMS': 0,
#  'ARE': 0.5584344528895916,
#  'VERY': 1.9042374526547452,
#  'GOOD': 0,
#  'MANY': 0,
#  'OTHER': 0,
#  'BRITONS': 0,
#  'WERE': 0,
#  'NOT': 0,
#  'SO': 0,
#  'SURE': 0,
#  'THOUGH': 0,
#  'GOVERNMENT': 0,
#  'SHOULDER': 0,
#  'NONE': 0,
#  'MILLION': 0,
#  'DEVELOPMENT': 0,
#  'COST': 0,
#  'HAS': 0,
#  'ALREADY': 0,
#  'POURED': 0,
#  'INTO': 0,
#  'HAVE': 0,
#  'SPEND': 0,
#  'PERHAPS': 0,
#  'BILLION': 0,
#  'MORE': 0,
#  'FLEET': 0,
#  'MISSILEPACKING': 0,
#  'SUBMARINES': 0,
#  'AT': 0.15849422071339697,
#  'BEST': 2.218730782557183,
#  'BRITISH': 0,
#  'BE': 0.2884704051689973,
#  'ABLE': 0,
#  'DESIGN': 0,
#  'BUILD': 0,
#  'PROVE': 0,
#  'BEFORE': 1.0434258731008188,
#  'THREE': 0,
#  'YEARS': 0,
#  'BRITAINS': 0,
#  'BOMBER': 0,
#  'PRESUMABLY': 0,
#  'BECOME': 0,
#  'OBSOLETE': 0,
#  'THEN': 0,
#  'WHAT': 0,
#  'TORY': 0,
#  'BACKBENCHERS': 0,
#  'LOUDLY': 0,
#  'SKEPTICAL': 0,
#  'CALL': 0,
#  'SMALL': 0,
#  'TYPE': 0,
#  'PACT': 0,
#  'WHICH': 0,
#  'STIPULATES': 0,
#  'SUBMARINE': 0,
#  'EXCEPT': 0,
#  'WHEN': 0,
#  'SUPREME': 0,
#  'NATIONAL': 0,
#  'INTERESTS': 0,
#  'INTERVENE': 0,
#  'MUST': 0,
#  'COMMITTED': 0,
#  'TRULY': 0,
#  'MULTILATERAL': 0,
#  'DOES': 0,
#  'MEAN': 0,
#  'EVENTUALLY': 0,
#  'DECIDE': 0,
#  'OR': 0,
#  'WHETHER': 0,
#  'JUSTIFY': 0,
#  'WITHDRAWAL': 0,
#  'PARTICULARLY': 0,
#  'IF': 0,
#  'THOSE': 0,
#  'CONFLICT': 0,
#  'POLICY': 0,
#  'BIGGEST': 0,
#  'QUESTION': 0,
#  'IS': 0.19230025684385083,
#  'FRANCES': 0,
#  'INCLUSION': 0,
#  'DELIBERATE': 0,
#  'PLOY': 0,
#  'JACK': 0,
#  'END': 0,
#  'LEAST': 0,
#  'DOWNGRADE': 0,
#  'PRIZED': 0,
#  'SPECIAL': 0,
#  'RELATIONSHIP': 0,
#  'CARTOONISTS': 0,
#  'WENT': 0,
#  'EVEN': 0,
#  'FARTHER': 0,
#  'ONLY': 0,
#  'SHOWED': 0,
#  'SUPERMAC': 0,
#  'JUMPING': 0,
#  'SUPERJACKS': 0,
#  'COMMANDS': 0,
#  'DE': 0,
#  'GAULLE': 0,
#  'ADENAUER': 0,
#  'WELL': 0,
#  'EDITH': 0,
#  'SAID': 1.880511539321976,
#  'FRENCH': 0,
#  'GOT': 0,
#  'DEVELOPING': 0,
#  'THEIR': 0,
#  'FRAPPE': 0,
#  'QUICK': 0,
#  'CROW': 0,
#  'VAUNTED': 0,
#  'TIES': 0,
#  'BROUGHT': 0,
#  'NOTHING': 0,
#  'HUMILIATION': 0,
#  'CONTRAST': 0,
#  'BRAGGED': 0,
#  'OFFICIALS': 0,
#  'FIASCO': 0,
#  'VINDICATED': 0,
#  'DECISION': 0,
#  'BOMBS': 0,
#  'DELIVERY': 0,
#  'SYSTEMS': 0,
#  'CHARLES': 0,
#  'PROMISED': 2.3584927249323417,
#  'REFLECT': 0,
#  'ON': 0,
#  'THERE': 0,
#  'LITTLE': 0,
#  'LIKELIHOOD': 0,
#  'HE': 0.46648329444242315,
#  'WOULD': 0.6180265500918373,
#  'ACCEPT': 0,
#  'ANY': 0,
#  'SUBJECT': 0,
#  'CONTROL': 0,
#  'GAULLES': 0,
#  'UNSWERVING': 0,
#  'CONVICTION': 0,
#  'RUSSIANS': 0,
#  'ACTUALLY': 0,
#  'INVADE': 0,
#  'WESTERN': 1.5700353645680714,
#  'NATION': 0,
#  'DIRECTLY': 0,
#  'ATTACKED': 0,
#  'MEANING': 0,
#  'INVITE': 0,
#  'DEVASTATION': 0,
#  'HELPING': 0,
#  'UNLIKE': 0,
#  'ALONG': 0,
#  'BEEN': 0,
#  'PLEDGED': 0,
#  'STRATEGIC': 0,
#  'RESPONSIBLE': 0,
#  'DEFENSE': 0,
#  'SAME': 0,
#  'LONG': 0,
#  'ARGUED': 0,
#  'ATLANTIC': 0,
#  'ALLIANCE': 0,
#  'COULD': 0,
#  'RUN': 0,
#  'MOST': 0,
#  'EFFICIENTLY': 0,
#  'TRIUMVIRATE': 0,
#  'INCLUDE': 0,
#  'AN': 0,
#  'EQUAL': 0,
#  'THIS': 0,
#  'MAJOR': 0,
#  'UNSPOKEN': 0,
#  'CONDITIONS': 0,
#  'MEMBERSHIP': 0,
#  'COMMON': 0,
#  'MARKET': 0,
#  'SUGGESTED': 0,
#  'POINTEDLY': 0,
#  'SHARE': 0,
#  'ADVANCED': 0,
#  'TECHNOLOGY': 0,
#  'REPLIED': 0,
#  'NONCOMMITTALLY': 0,
#  'DISCUSS': 0,
#  'TOLD': 0,
#  'GUEST': 0,
#  'HAUTEUR': 0,
#  'CASE': 0,
#  'DO': 0,
#  'EASE': 0,
#  'ENTRY': 0,
#  'GOITALONE': 0,
#  'GRANDEUR': 0,
#  'KONRAD': 0,
#  'HAND': 0,
#  'FEARFUL': 0,
#  'SNAP': 0,
#  'UP': 0.4054651081081644,
#  'WAY': 0,
#  'ACHIEVE': 0,
#  'GOAL': 0,
#  'THREENATION': 0,
#  'DIRECTORATE': 0,
#  'VOWED': 0,
#  'MANUFACTURE': 0,
#  'WEAPONS': 0,
#  'INCREASINGLY': 0,
#  'APPREHENSIVE': 0,
#  'WITHOUT': 0,
#  'THEM': 0,
#  'SAY': 0,
#  'USE': 0,
#  'WEST': 0,
#  'GERMANY': 0,
#  'RELEGATED': 0,
#  'SECONDCLASS': 0,
#  'CITIZENSHIP': 0,
#  'OFFICIAL': 0,
#  'BULLETIN': 0,
#  'REVIVED': 0,
#  'OLD': 0,
#  'BITTER': 0,
#  'CRY': 0,
#  'PLEAS': 0,
#  'GREATER': 0,
#  'RELIANCE': 0,
#  'CONVENTIONAL': 0,
#  'FORCES': 0,
#  'AIMED': 3.214158834990062,
#  'RAISING': 0,
#  'GERMAN': 0,
#  'CANNON': 0,
#  'FODDER': 0,
#  'ATOMIC': 0,
#  'KNIGHTS': 0,
#  'FROSTY': 0,
#  'LETTER': 0,
#  'CHANCELLOR': 0,
#  'SUPPLIES': 0,
#  'ALMOST': 0,
#  'PER': 0,
#  'CENT': 0,
#  'GROUND': 0,
#  'STRENGTH': 0,
#  'INTEND': 0,
#  'RAISE': 0,
#  'DIVISIONS': 0,
#  'WARFARE': 0,
#  'YET': 0,
#  'PLANNERS': 0,
#  'REASON': 0,
#  'CREDIBLE': 0,
#  'SOVIET': 0,
#  'ATTACK': 0,
#  'STRONG': 0,
#  'ARMY': 0,
#  'BACKED': 0,
#  'VAST': 0,
#  'ARSENAL': 0,
#  'FACT': 0,
#  'NEVER': 0,
#  'USED': 0,
#  'INDEPENDENTLY': 0,
#  'AGAINST': 0,
#  'RUSSIA': 0,
#  'INVITING': 0,
#  'DEVASTATING': 0,
#  'RETALIATION': 0,
#  'EFFORTS': 0,
#  'MANAGED': 0,
#  'CREATE': 0,
#  'CAPACITY': 0,
#  'REPRESENTS': 0,
#  'POWER': 0,
#  'JUST': 2.470375647347721,
#  'DAMNED': 0,
#  'NUISANCE': 0,
#  'STATE': 0,
#  'DEPARTMENT': 0,
#  'MEANS': 0,
#  'MILITARILY': 0,
#  'WE': 0,
#  'EXPECTED': 0,
#  'BAIL': 0,
#  'OUT': 0.41975106535564094,
#  'COUNTRY': 0,
#  'THROWS': 0,
#  'PEA': 0,
#  'ANYONE': 0,
#  'ELSE': 0,
#  'HARDLY': 0,
#  'AGREE': 0,
#  'UNTIL': 0,
#  'BECOMES': 0,
#  'MAKES': 0,
#  'IMMEDIATE': 0,
#  'SENSE': 0,
#  'TOO': 0,
#  'MAY': 0,
#  'FIND': 0,
#  'NATOCONTROLLED': 0,
#  'POSSIBLE': 0,
#  'SUCCESSOR': 0,
#  'EUROPEAN': 0,
#  'MINUTEMAN': 0,
#  'ANSWER': 0,
#  'SPIRALING': 0,
#  'DIMINISHING': 0,
#  'VALUE': 0,
#  'WHOS': 0,
#  'CHARGE': 0,
#  'HERE': 0,
#  'NIKITA': 0,
#  'KHRUSHCHEV': 0,
#  'LAUNCHED': 0,
#  'GRANDIOSE': 0,
#  'VIRGIN': 0,
#  'LANDS': 0,
#  'GAMBLE': 0,
#  'PART': 0,
#  'PLOW': 0,
#  'ACRES': 0,
#  'MARGINAL': 0,
#  'LAND': 0,
#  'KAZAKHSTAN': 0,
#  'SETTLE': 0,
#  'COMMUNIST': 0,
#  'PIONEERS': 0,
#  'PLANT': 0,
#  'PRODUCE': 0,
#  'HUGE': 0,
#  'QUANTITIES': 0,
#  'DESPERATELY': 0,
#  'NEEDED': 0,
#  'GRAIN': 0,
#  'WITHIN': 0,
#  'TWO': 0,
#  'NIKITAS': 0,
#  'SCHEME': 0,
#  'FLOPPED': 0,
#  'ENOUGH': 0,
#  'RAINFALL': 0,
#  'DID': 0,
#  'TAKE': 0,
#  'TRACTOR': 0,
#  'LIFE': 0,
#  'BLEAK': 0,
#  'FRONTIER': 0,
#  'EACH': 0,
#  'HARVEST': 0,
#  'LOWER': 0,
#  'THAN': 0,
#  'PREVIOUS': 0,
#  'WORST': 0,
#  'YEAR': 0,
#  'DELIVERED': 0,
#  'HALF': 0,
#  'QUOTAS': 0,
#  'NATURALLY': 0,
#  'TAKES': 0,
#  'BLAME': 0,
#  'AGO': 0,
#  'FOUND': 0,
#  'SCAPEGOAT': 0,
#  'PARTY': 0,
#  'BOSS': 0,
#  'NIKOLAI': 0,
#  'BELYAEV': 0,
#  'FIRED': 0,
#  'HIM': 2.647758615368292,
#  'ERRORS': 0,
#  'BELYAEVS': 0,
#  'DINMUKHAMED': 0,
#  'KUNAEV': 0,
#  'SIMILARLY': 0,
#  'BOUNCED': 0,
#  'LAPSES': 0,
#  'WORK': 0,
#  'MEASURE': 0,
#  'MOSCOW': 0,
#  'ALSO': 0,
#  'PURGED': 0,
#  'FORMER': 0,
#  'PREMIER': 0,
#  'TERRITORY': 0,
#  'LOCAL': 0,
#  'PARTYS': 0,
#  'CENTRAL': 0,
#  'COMMITTEE': 0,
#  'COINCIDENCE': 0,
#  'IGNATOV': 0,
#  'ONETIME': 0,
#  'CRONY': 0,
#  'ABRUPTLY': 0,
#  'LEFT': 0,
#  'POST': 0,
#  'DEPUTY': 0,
#  'NINE': 0,
#  'MONTHS': 0,
#  'JOB': 0,
#  'FARM': 0,
#  'EXPERT': 0,
#  'MISFORTUNE': 0,
#  'BOOST': 0,
#  'FOOD': 0,
#  'PRODUCTION': 0,
#  'BERLIN': 0,
#  'HANS': 0,
#  'WEIDNER': 0,
#  'HOPING': 0,
#  'ESCAPE': 0,
#  'DRAB': 0,
#  'EAST': 0,
#  'MAKE': 0,
#  'ODDS': 0,
#  'CRIPPLE': 0,
#  'CRUTCHES': 0,
#  'LIVED': 0,
#  'VILLAGE': 0,
#  'NEUGERSDORF': 0,
#  'MILES': 0,
#  'SOUTHEAST': 0,
#  'FREEDOM': 0,
#  'ASSET': 0,
#  'BUS': 0,
#  'OPERATED': 0,
#  'REGIME': 0,
#  'UGLY': 0,
#  'THING': 0,
#  'ANCIENT': 0,
#  'CHASSIS': 0,
#  'CREAKED': 0,
#  'ENGINE': 0,
#  'COUGHED': 0,
#  'CREAMCOLORED': 0,
#  'COAT': 0,
#  'PAINT': 0,
#  'DISGUISE': 0,
#  'WELTS': 0,
#  'BRUISES': 0,
#  'DECADES': 0,
#  'CHUGGING': 0,
#  'SERVICE': 2.463853240590168,
#  'READY': 0,
#  'JUNK': 0,
#  'PILE': 0,
#  'DECIDED': 0,
#  'PRESS': 0,
#  'SHARP': 0,
#  'BLADES': 0,
#  'HAZARDS': 0,
#  'GREAT': 0,
#  'JOURNEY': 0,
#  'BORDER': 0,
#  'SIGNED': 0,
#  'FELLOW': 0,
#  'VILLAGER': 0,
#  'JURGEN': 0,
#  'WAGNER': 0,
#  'WHEEL': 0,
#  'EIGHT': 0,
#  'DAYS': 1.2937819879399133,
#  'CHRISTMAS': 0,
#  'PAIR': 0,
#  'BEGAN': 0,
#  'FEVERISH': 0,
#  'PREPARATIONS': 0,
#  'WEIDNERS': 0,
#  'GARAGE': 0,
#  'ATTACHED': 0,
#  'HEAVY': 0,
#  'SNOWPLOW': 0,
#  'FRONT': 0,
#  'SNOW': 0,
#  'SCOOP': 0,
#  'AWAY': 0,
#  'OBSTACLES': 0,
#  'KNEW': 0,
#  'AWAITED': 0,
#  'ROADBLOCKS': 0,
#  'AHEAD': 0,
#  'SIX': 0,
#  'LUGS': 0,
#  'BOLTED': 0,
#  'TOUGHEST': 0,
#  'STEEL': 0,
#  'AFFIXED': 0,
#  'WHIRLING': 0,
#  'EDGES': 0,
#  'CHOP': 0,
#  'BARBED': 0,
#  'WIRE': 0,
#  'BITS': 0,
#  'WEDGED': 0,
#  'ONEQUARTERINCH': 0,
#  'SECTIONS': 0,
#  'PLATE': 0,
#  'INSIDE': 0,
#  'STOP': 0,
#  'BULLETS': 0,
#  'EVE': 0,
#  'PILED': 0,
#  'WIVES': 0,
#  'FOUR': 0,
#  'CHILDREN': 0,
#  'ABOARD': 0,
#  'FORGETTING': 0,
#  'TONS': 0,
#  'HOUSEHOLD': 0,
#  'BELONGINGS': 0,
#  'ADDED': 0,
#  'PROTECTION': 0,
#  'PLOTTERS': 0,
#  'SHOVELED': 0,
#  'TON': 0,
#  'COAL': 0,
#  'POTATOES': 0,
#  'CHUGGED': 0,
#  'OFF': 0.8378860262048571,
#  'NORTH': 0,
#  'TOWARD': 0,
#  'ROADS': 0,
#  'PATROLS': 0,
#  'REACHED': 0,
#  'WALL': 0,
#  'PLANNED': 0,
#  'SWING': 0,
#  'ORDER': 0,
#  'ENTER': 0,
#  'EASTWEST': 0,
#  'AUTOBAHN': 0,
#  'LEADING': 0,
#  'SECTOR': 0,
#  'CITY': 0,
#  'EN': 0,
#  'ROUTE': 0,
#  'RADIATOR': 0,
#  'FROZE': 0,
#  'SUBZERO': 0,
#  'WEATHER': 0,
#  'FIXED': 0,
#  'FEW': 0,
#  'TIRE': 0,
#  'BLEW': 0,
#  'KIDS': 0,
#  'CRYING': 0,
#  'SHIVERING': 0,
#  'COLD': 0,
#  'PANIC': 0,
#  'ARRIVED': 0,
#  'DREWITZ': 0,
#  'HEAVILY': 0,
#  'GUARDED': 0,
#  'CHECKPOINT': 0,
#  'ENTIRE': 0,
#  'RECONSIDER': 0,
#  'FLYING': 0,
#  'WAHAH': 0,
#  'SHRIEKED': 0,
#  'POLICETYPE': 0,
#  'KLAXONS': 0,
#  'THOUGHTFULLY': 0,
#  'INSTALLED': 0,
#  'ADVANCE': 0,
#  'GUARDS': 0,
#  'OBEDIENTLY': 0,
#  'RAISED': 0,
#  'BARRIERS': 0,
#  'DOING': 0,
#  'EMERGENCY': 0,
#  'DUTY': 0,
#  'SUDDENLY': 0,
#  'SHOOTING': 0,
#  'LATE': 0,
#  'MPH': 0,
#  'CRASHING': 0,
#  'THROUGH': 1.0300923422313535,
#  'SECOND': 0,
#  'BARRIER': 0,
#  'YARDS': 0,
#  'THIRD': 0,
#  'WINDSHIELD': 0,
#  'SMASHED': 0,
#  'PASSENGERS': 0,
#  'SHAKEN': 0,
#  'CARGO': 0,
#  'EVERY': 0,
#  'CORNER': 0,
#  'CAB': 0,
#  'FINALLY': 0,
#  'LURCHED': 0,
#  'DOWN': 0,
#  'ROAD': 2.463853240590168,
#  'WHERE': 0,
#  'COMMUNISTS': 0,
#  'LONGER': 0,
#  'MATTERED': 0,
#  'FOOT': 0,
#  'JAIL': 4.767621065833263,
#  'PAVED': 4.948759890378168,
#  'NONOBJECTIVE': 6.0473721790462776,
#  'ART': 10.687396587774833,
#  'SINCE': 0.8216255053330768,
#  'KREMLINS': 3.744787086052232,
#  'SHARPEST': 4.948759890378168,
#  'BARBS': 6.0473721790462776,
#  'THESE': 1.9698347351405585,
#  'MODERN': 2.6461747973841225,
#  'ESPIONAGE': 3.4824228215847413,
#  'MATTER': 2.5210116544301164,
#  'KGBS': 6.0473721790462776,
#  'COPS': 5.7386366973966645,
#  'TURN': 2.0583881324820035,
#  'VICTIM': 4.101462029990965,
#  'WHOSE': 2.864503324410037,
#  'WRONGDOINGS': 6.0473721790462776,
#  'COMBINED': 3.8501476017100584,
#  'BOTH': 1.3199843603339374,
#  'EVILS': 6.0473721790462776,
#  'TURNED': 1.6779243265792565,
#  'LENINGRAD': 4.255612709818223,
#  'PHYSICS': 5.354224998486333,
#  'TEACHER': 12.304386089972894,
#  'TASTE': 3.744787086052232,
#  'ABSTRACT': 9.322155635852775,
#  'PAINTING': 4.437934266612178,
#  'ALLEGEDLY': 3.9679306373664422,
#  'LED': 2.1972245773362196,
#  'JOIN': 2.751535313041949,
#  'SPY': 3.4083148494310196,
#  'POLICE': 1.5814640603916943,
#  'SPOTTED': 4.255612709818223,
#  'RUDOLF': 4.661077817926388,
#  'FRIEDMAN': 24.18948871618511,
#  'MUTTERED': 4.948759890378168,
#  'UNCOMPLIMENTARY': 6.0473721790462776,
#  'REMARKS': 3.8501476017100584,
#  'ABOUT': 1.834946928246409,
#  'SOCIALIST': 2.263182545128017,
#  'REALISM': 4.948759890378168,
#  'WHILE': 1.1057297564369737,
#  'STROLLING': 5.354224998486333,
#  'LENINGRADS': 5.354224998486333,
#  'RUSSIAN': 2.0961284604648505,
#  'MUSEUM': 4.437934266612178,
#  'WELLDRESSED': 4.661077817926388,
#  'TOURIST': 3.744787086052232,
#  'APPROACHED': 4.948759890378168,
#  'ENTHUSIASTICALLY': 4.948759890378168,
#  'SHARED': 3.4824228215847413,
#  'SENTIMENTS': 4.948759890378168,
#  'SEND': 3.0516399054922867,
#  'REPRODUCTIONS': 6.0473721790462776,
#  'AVANTGARDE': 5.354224998486333,
#  'PAINTINGS': 4.255612709818223,
#  'AMERICA': 3.002849741322855,
#  'PICTURE': 3.1570004211501135,
#  'LIKED': 3.8501476017100584,
#  'INDIGNANTLY': 4.437934266612178,
#  'CHAOS': 3.9679306373664422,
#  'BLACK': 1.888489095686606,
#  'RED': 1.2433511343130215,
#  'BLUE': 2.8693183486983322,
#  'SPLOTCHES': 6.0473721790462776,
#  'CAPTIONED': 6.0473721790462776,
#  'I': 1.0775588794702773,
#  'NEED': 2.3584927249323417,
#  'YOU': 1.3024400506830278,
#  'TONIGHT': 5.354224998486333,
#  'SOON': 1.7707060600302227,
#  'GETTING': 2.4364542664020536,
#  'MESSAGES': 4.661077817926388,
#  'WRITTEN': 3.5624655292582776,
#  'INVISIBLE': 5.354224998486333,
#  'INK': 4.948759890378168,
#  'PREPARED': 2.6461747973841225,
#  'DELIVER': 4.661077817926388,
#  'INFORMATION': 2.956329725687962,
#  'REMOTE': 3.4083148494310196,
#  'THEORETICAL': 4.661077817926388,
#  'ARGUMENTS': 4.437934266612178,
#  'POLICEMOVED': 6.0473721790462776,
#  'HUSTLED': 3.744787086052232,
#  'CONGO': 0,
#  'ROUND': 0,
#  'SOUND': 0,
#  'KATANGA': 0,
#  'PROVINCE': 0,
#  'THUNK': 0,
#  'MORTAR': 0,
#  'SHELLS': 0,
#  'RATTLE': 0,
#  'MACHINE': 0,
#  'GUNS': 0,
#  'UNEASY': 0,
#  'TWELVEMONTH': 0,
#  'TRUCE': 0,
#  'UN': 0,
#  'TROOPS': 0,
#  'KATANGAS': 0,
#  'SECESSIONIST': 0,
#  'MOISE': 0,
#  'TSHOMBE': 0,
#  'MINOR': 0,
#  'INCIDENTS': 0,
#  'SEPTEMBER': 0,
#  'TURMOIL': 0,
#  'BLUEHELMETED': 0,
#  'SOLDIERS': 0,
#  'SWARMED': 0,
#  'ELISABETHVILLE': 0,
#  'SEIZED': 0,
#  'HIGHWAYS': 0,
#  'SWEDISH': 0,
#  'SAAB': 0,
#  'JETS': 0,
#  'SWOOPED': 0,
#  'LOW': 0,
#  'AIRFIELD': 0,
#  'KOLWEZI': 0,
#  'DESTROYING': 0,
#  'PLANES': 0,
#  'SETTING': 0,
#  'OIL': 0,
#  'TANKS': 0,
#  'ABLAZE': 0,
#  'SKIRMISHES': 0,
#  'SEVEN': 0,
#  'DEAD': 0,
#  'FIGHTING': 0,
#  'RESIDENTS': 0,
#  'LAFFAIRE': 0,
#  'SIMBA': 0,
#  'REFERENCE': 0,
#  'BEER': 0,
#  'BREW': 0,
#  'SIDES': 0,
#  'GUZZLED': 0,
#  'BOOZEDUP': 0,
#  'KATANGESE': 0,
#  'GENDARMES': 0,
#  'OPENED': 0,
#  'FIRE': 0,
#  'DETACHMENT': 0,
#  'ETHIOPIAN': 0,
#  'SUBURBAN': 0,
#  'LUBUMBASHI': 0,
#  'DESCRIBED': 0,
#  'MATTERS': 0,
#  'TIPSY': 0,
#  'ETHIOPIANS': 0,
#  'STARTED': 0,
#  'SCRAMBLING': 0,
#  'ATOP': 0,
#  'FT': 0,
#  'SLAG': 0,
#  'HEAP': 0,
#  'OUTSIDE': 0,
#  'BIG': 0,
#  'UNION': 0,
#  'MINIERE': 0,
#  'TAKING': 0,
#  'POTSHOTS': 0,
#  'FIREWORKS': 0,
#  'NEXT': 0,
#  'GOLF': 0,
#  'COURSE': 0,
#  'OUTSKIRTS': 0,
#  'TOOK': 0,
#  'OCCASION': 0,
#  'SHOOT': 0,
#  'UNARMED': 0,
#  'HELICOPTER': 0,
#  'MOVING': 0,
#  'OVERHEAD': 0,
#  'STONED': 0,
#  'SURVIVING': 0,
#  'CREWMEN': 0,
#  'PUMMELED': 0,
#  'RIFLE': 0,
#  'BUTTS': 0,
#  'YEAROLD': 0,
#  'SIKH': 0,
#  'LIEUTENANT': 0,
#  'LAY': 0,
#  'HELPLESS': 0,
#  'GUN': 0,
#  'SLUG': 0,
#  'ABDOMEN': 0,
#  'DIED': 0,
#  'UNATTENDED': 0,
#  'HOURS': 0,
#  'INDIAN': 0,
#  'BRIGADIER': 0,
#  'REGINALD': 0,
#  'NORONHA': 0,
#  'COMMANDER': 0,
#  'CAPITAL': 0,
#  'FURIOUS': 0,
#  'GOING': 0,
#  'WAIT': 0,
#  'LATER': 0,
#  'GUARD': 0,
#  'WARNING': 0,
#  'SHOT': 0,
#  'SOLDIER': 0,
#  'APPROACHING': 0,
#  'UNHURT': 0,
#  'ROLLED': 0,
#  'HILL': 0,
#  'SEARCH': 0,
#  'COVER': 0,
#  'COMRADES': 0,
#  'THOUGHT': 0,
#  'HIT': 0,
#  'POSITIONS': 0,
#  'AROUND': 0,
#  'UNDER': 0,
#  'AGREED': 0,
#  'CEASEFIRE': 0,
#  'MEN': 0,
#  'KEPT': 0,
#  'RIGHT': 0,
#  'MAD': 0,
#  'CROSS': 0,
#  'RAMPAGING': 0,
#  'TOWNSHIP': 0,
#  'FIRING': 0,
#  'ANYTHING': 0,
#  'MOVED': 0,
#  'KILLING': 0,
#  'CLAIMED': 0,
#  'LOST': 0,
#  'GAVE': 0,
#  'EXCUSE': 0,
#  'MANHATTAN': 0,
#  'HEADQUARTERS': 0,
#  'ORDERS': 0,
#  'FLASHED': 0,
#  'MAN': 0,
#  'NECESSARY': 0,
#  'ACTION': 0,
#  'SELFDEFENSE': 0,
#  'RESTORE': 0,
#  'SPEARHEADED': 0,
#  'TOUGH': 0,
#  'GURKHAS': 0,
#  'METHODICALLY': 0,
#  'SWEPT': 0,
#  'DISORGANIZED': 0,
#  'GUARDPOSTS': 0,
#  'NORTHERN': 0,
#  'RHODESIA': 0,
#  'LINES': 0,
#  'FELL': 0,
#  'FRAY': 0,
#  'LEAVING': 0,
#  'SHABBY': 0,
#  'POP': 0,
#  'LIGHT': 0,
#  'WATER': 0,
#  'PHONES': 0,
#  'SPEARS': 0,
#  'ARROWS': 0,
#  'DEMANDED': 0,
#  'ONCE': 0,
#  'WARNED': 0,
#  'UNLESS': 0,
#  'COMPLIED': 0,
#  'MINUTES': 0,
#  'GENERAL': 0,
#  'WAR': 0,
#  'BEGIN': 0,
#  'REJECTED': 0,
#  'ULTIMATUM': 0,
#  'ALLOUT': 0,
#  'AIR': 0,
#  'OFFENSIVE': 0,
#  'BRIGADE': 0,
#  'STORMED': 0,
#  'CAPTURED': 0,
#  'GENDARMERIE': 0,
#  'KARAVIA': 0,
#  'MILE': 0,
#  'RESISTANCE': 0,
#  'ANOTHER': 0,
#  'COLUMN': 0,
#  'NORTHWEST': 0,
#  'JADOTVILLE': 0,
#  'HEART': 0,
#  'COPPER': 0,
#  'BELT': 0,
#  'GIVES': 0,
#  'REVENUES': 0,
#  'ANNOUNCED': 0,
#  'TAKEN': 0,
#  'ELISABETHVILLES': 0,
#  'OFFICE': 0,
#  ...}

# %%
len(vectors)
# Out:
# 423

# %%
len(vectors[4])
# Out:
# 22496

# %%
def cosine_similarity(vec1, vec2):
    # Compute the dot product of the two vectors.
    # Since both vectors contain all terms (even with 0 values),
    # it's safe to just iterate over one of them.
    dot_product = sum(vec1[term] * vec2[term] for term in vec1)

    # Compute the Euclidean norm (magnitude) of each vector.
    norm1 = sqrt(sum(value**2 for value in vec1.values()))
    norm2 = sqrt(sum(value**2 for value in vec2.values()))

    # Avoid division by zero: if either vector is zero, return 0 similarity
    if norm1 == 0 or norm2 == 0:
        return 0.0

    # Return the cosine similarity
    return dot_product / (norm1 * norm2)

# %%
vectors = documents_as_vectors(articles)
sim = cosine_similarity({'ALLIES':1}, vectors[0])
print("Cosine similarity:", sim)
# Out:
# Cosine similarity: 0.050928058257171005
